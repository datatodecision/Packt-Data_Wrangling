# %%
###################################################################################
# Course : Data Preparation
# Course code: DSC540
# Weeks: 7 and 8
# Script name : DSC540_Shekhar_Week7&8.ipynb
# Created Date : Apr 23rd 2023
# Created By : Manish Shekhar
###################################################################################

# %%
# importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the candy hierarchy data file 
df_candy_hier = pd.read_csv("candyhierarchy2017.csv", encoding ='latin1')

# %%
# checking the data
df_candy_hier.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Q6 | Any full-sized candy bar Q6 | Black Jacks  ... Q8: DESPAIR OTHER  \
# 0                           NaN              NaN  ...               NaN
# 1                           JOY              MEH  ...               NaN
# 2                           NaN              NaN  ...               NaN
# 3                           JOY              MEH  ...               NaN
# 4                           JOY          DESPAIR  ...               NaN
#
#                                   Q9: OTHER COMMENTS      Q10: DRESS  \
# 0                                                NaN             NaN
# 1  Bottom line is Twix is really the only candy w...  White and gold
# 2                                                NaN             NaN
# 3                             Raisins can go to hell  White and gold
# 4                                                NaN  White and gold
#
#   Unnamed: 113 Q11: DAY Q12: MEDIA [Daily Dish] Q12: MEDIA [Science]  \
# 0          NaN      NaN                     NaN                  NaN
# 1          NaN   Sunday                     NaN                  1.0
# 2          NaN      NaN                     NaN                  NaN
# 3          NaN   Sunday                     NaN                  1.0
# 4          NaN   Friday                     NaN                  1.0
#
#   Q12: MEDIA [ESPN] Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 0               NaN                NaN                      NaN
# 1               NaN                NaN                 (84, 25)
# 2               NaN                NaN                      NaN
# 3               NaN                NaN                 (75, 23)
# 4               NaN                NaN                 (70, 10)
#
# [5 rows x 120 columns]

# %%
# Reading Metobjects data file
df_met = pd.read_csv("MetObjects.csv",encoding ='latin1')

# %%
# checking the data
df_met.head()
# Out:
#   Object Number Is Highlight Is Public Domain Object ID         Department  \
# 0    1979.486.1        FALSE            FALSE         1  The American Wing
# 1    1980.264.5        FALSE            FALSE         2  The American Wing
# 2      67.265.9        FALSE            FALSE         3  The American Wing
# 3     67.265.10        FALSE            FALSE         4  The American Wing
# 4     67.265.11        FALSE            FALSE         5  The American Wing
#
#   Object Name                         Title Culture Period Dynasty  ...  \
# 0        Coin  One-dollar Liberty Head Coin     NaN    NaN     NaN  ...
# 1        Coin  Ten-dollar Liberty Head Coin     NaN    NaN     NaN  ...
# 2        Coin    Two-and-a-Half Dollar Coin     NaN    NaN     NaN  ...
# 3        Coin    Two-and-a-Half Dollar Coin     NaN    NaN     NaN  ...
# 4        Coin    Two-and-a-Half Dollar Coin     NaN    NaN     NaN  ...
#
#   Locale Locus Excavation River Classification Rights and Reproduction  \
# 0    NaN   NaN        NaN   NaN          Metal                     NaN
# 1    NaN   NaN        NaN   NaN          Metal                     NaN
# 2    NaN   NaN        NaN   NaN          Metal                     NaN
# 3    NaN   NaN        NaN   NaN          Metal                     NaN
# 4    NaN   NaN        NaN   NaN          Metal                     NaN
#
#                                       Link Resource Metadata Date  \
# 0  http://www.metmuseum.org/art/collection/search/1           NaN
# 1  http://www.metmuseum.org/art/collection/search/2           NaN
# 2  http://www.metmuseum.org/art/collection/search/3           NaN
# 3  http://www.metmuseum.org/art/collection/search/4           NaN
# 4  http://www.metmuseum.org/art/collection/search/5           NaN
#
#                                  Repository Tags
# 0  Metropolitan Museum of Art, New York, NY  NaN
# 1  Metropolitan Museum of Art, New York, NY  NaN
# 2  Metropolitan Museum of Art, New York, NY  NaN
# 3  Metropolitan Museum of Art, New York, NY  NaN
# 4  Metropolitan Museum of Art, New York, NY  NaN
#
# [5 rows x 44 columns]

# %% [markdown]
# ### Transform 1 (Chapter 7) : Check for nulls and get rid of data if we have null in key column "Object Number"

# %%
# check how many not nulls we have in Object Number column
df_met['Object Number'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 12108 entries, 0 to 12107
# Series name: Object Number
# Non-Null Count  Dtype
# --------------  -----
# 12087 non-null  object
# dtypes: object(1)
# memory usage: 94.7+ KB

# %%
# check the total count of records
df_met.shape

# we see that we have total of 12108 records and 12087 have Object Number populated on them
# Thus we can get rid of records with Object Number null
# Out:
# (12108, 44)

# %%
# Filtering out records having Object Number as Null
df_met_filtered = df_met[~df_met['Object Number'].isnull()]

# %%
# check shape of df_met_filtered
df_met_filtered.shape

# Data is filtered out, make sure we do not have any nulls in Object Number field now
# Out:
# (12087, 44)

# %%
df_met_filtered['Object Number'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 12087 entries, 0 to 12107
# Series name: Object Number
# Non-Null Count  Dtype
# --------------  -----
# 12087 non-null  object
# dtypes: object(1)
# memory usage: 188.9+ KB

# %% [markdown]
# ### Transform 2 (Chapter 7) : Checking and removing duplicates

# %%
# Using pandas drop_duplicates to drop dupes in the dataset
df_no_dupes = df_met_filtered.drop_duplicates()

# %%
# check the count of records again
df_no_dupes.shape

# we clearly dropped quite a bit of duplicates in the data
# Out:
# (11922, 44)

# %% [markdown]
# ### Transform 3 (Chapter 8) : Merging two datasets

# %%
# Reading another Candy dataset CANDYDATA.xlsx
df_candy = pd.read_excel("CANDYDATA.xlsx")

# %%
# check data
df_candy.head(100)
# Out:
#                                                  ITEM    JOY  DESPAIR  \
# 0                             York Peppermint Patties    634       78
# 1                                Whole Wheat anything     21      419
# 2                                         White Bread     15      473
# 3                                             Vicodin    323      210
# 4                                                Twix    770       26
# ..                                                ...    ...      ...
# 82                                        Black Jacks     34      252
# 83                           Any full-sized candy bar    828       13
# 84  Anonymous brown globs that come in black and o...    120      663
# 85                                      100 Grand Bar    570       34
# 86                                                NaN  26204    17563
#
#     NET FEELIES  NET CLOUT  DESPAIR (NEG)
# 0         556.0   1.639118          -78.0
# 1        -398.0   1.012938         -419.0
# 2        -458.0   1.123440         -473.0
# 3         113.0   1.227036         -210.0
# 4         744.0   1.832497          -26.0
# ..          ...        ...            ...
# 82       -218.0   0.658410         -252.0
# 83        815.0   1.936093          -13.0
# 84       -543.0   1.802569         -663.0
# 85        536.0   1.390488          -34.0
# 86          NaN        NaN            NaN
#
# [87 rows x 6 columns]

# %%
# check candy hierarchy data
pd.set_option('display.max_columns', None)
df_candy_hier.head(100)
# Out:
#     Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE    Q4: COUNTRY  \
# 0      90258773            NaN        NaN     NaN            NaN
# 1      90272821             No       Male      44           USA
# 2      90272829            NaN       Male      49            USA
# 3      90272840             No       Male      40             us
# 4      90272841             No       Male      23            usa
# ..          ...            ...        ...     ...            ...
# 95     90273049             No       Male      50  United States
# 96     90273050             No       Male      64            usa
# 97     90273051             No       Male      42            Usa
# 98     90273053             No     Female      35            USA
# 99     90273055             No     Female      44             US
#
#    Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                               NaN                NaN
# 1                                NM                MEH
# 2                          Virginia                NaN
# 3                                or                MEH
# 4                          exton pa                JOY
# ..                              ...                ...
# 95                         Maryland                JOY
# 96                           alaska                NaN
# 97                               Ny                NaN
# 98      Colorado, Jefferson county                 MEH
# 99                       California                JOY
#
#    Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                 NaN
# 1                                             DESPAIR
# 2                                                 NaN
# 3                                             DESPAIR
# 4                                             DESPAIR
# ..                                                ...
# 95                                                MEH
# 96                                                NaN
# 97                                                NaN
# 98                                            DESPAIR
# 99                                            DESPAIR
#
#    Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 0                            NaN              NaN                      NaN
# 1                            JOY              MEH                  DESPAIR
# 2                            NaN              NaN                      NaN
# 3                            JOY              MEH                      MEH
# 4                            JOY          DESPAIR                      MEH
# ..                           ...              ...                      ...
# 95                           JOY          DESPAIR                      JOY
# 96                           NaN              NaN                      NaN
# 97                           JOY              NaN                      MEH
# 98                           JOY              NaN                      NaN
# 99                           MEH          DESPAIR                      MEH
#
#    Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 0                            NaN              NaN                NaN
# 1                        DESPAIR          DESPAIR            DESPAIR
# 2                            NaN              NaN                NaN
# 3                        DESPAIR              MEH            DESPAIR
# 4                        DESPAIR              MEH            DESPAIR
# ..                           ...              ...                ...
# 95                           JOY              JOY            DESPAIR
# 96                           NaN              NaN                NaN
# 97                           NaN              JOY            DESPAIR
# 98                           NaN          DESPAIR            DESPAIR
# 99                           JOY              JOY            DESPAIR
#
#    Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 0                     NaN               NaN                     NaN
# 1                 DESPAIR           DESPAIR                     MEH
# 2                     NaN               NaN                     NaN
# 3                 DESPAIR               MEH                     MEH
# 4                 DESPAIR               MEH                     MEH
# ..                    ...               ...                     ...
# 95                DESPAIR               JOY                 DESPAIR
# 96                    NaN               NaN                     NaN
# 97                DESPAIR               JOY                     MEH
# 98                DESPAIR               JOY                     JOY
# 99                DESPAIR               MEH                     JOY
#
#    Q6 | Candy Corn  \
# 0              NaN
# 1              MEH
# 2              NaN
# 3          DESPAIR
# 4          DESPAIR
# ..             ...
# 95         DESPAIR
# 96             NaN
# 97             JOY
# 98         DESPAIR
# 99             JOY
#
#    Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 0                                                 NaN
# 1                                             DESPAIR
# 2                                                 NaN
# 3                                             DESPAIR
# 4                                             DESPAIR
# ..                                                ...
# 95                                            DESPAIR
# 96                                                NaN
# 97                                                JOY
# 98                                            DESPAIR
# 99                                            DESPAIR
#
#    Q6 | Caramellos Q6 | Cash, or other forms of legal tender Q6 | Chardonnay  \
# 0              NaN                                       NaN             NaN
# 1              MEH                                       JOY             MEH
# 2              NaN                                       NaN             NaN
# 3              MEH                                       JOY             MEH
# 4              JOY                                       MEH             JOY
# ..             ...                                       ...             ...
# 95             JOY                                       JOY             JOY
# 96             NaN                                       NaN             NaN
# 97             NaN                                   DESPAIR             NaN
# 98             JOY                                       MEH             NaN
# 99             JOY                                       MEH         DESPAIR
#
#    Q6 | Chick-o-Sticks (we donÕt know what that is) Q6 | Chiclets  \
# 0                                               NaN           NaN
# 1                                           DESPAIR       DESPAIR
# 2                                               NaN           NaN
# 3                                               JOY           MEH
# 4                                           DESPAIR       DESPAIR
# ..                                              ...           ...
# 95                                              JOY           JOY
# 96                                              NaN           NaN
# 97                                              NaN       DESPAIR
# 98                                          DESPAIR       DESPAIR
# 99                                          DESPAIR           MEH
#
#    Q6 | Coffee Crisp Q6 | Creepy Religious comics/Chick Tracts  \
# 0                NaN                                       NaN
# 1            DESPAIR                                   DESPAIR
# 2                NaN                                       NaN
# 3            DESPAIR                                   DESPAIR
# 4                MEH                                   DESPAIR
# ..               ...                                       ...
# 95           DESPAIR                                   DESPAIR
# 96               NaN                                       NaN
# 97               JOY                                       JOY
# 98               NaN                                       NaN
# 99               MEH                                   DESPAIR
#
#    Q6 | Dental paraphenalia Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 0                       NaN       NaN            NaN                NaN
# 1                   DESPAIR       MEH            JOY            DESPAIR
# 2                       NaN       NaN            NaN                NaN
# 3                   DESPAIR       JOY            JOY                MEH
# 4                   DESPAIR       MEH            JOY            DESPAIR
# ..                      ...       ...            ...                ...
# 95                  DESPAIR       MEH            JOY            DESPAIR
# 96                      NaN       NaN            NaN                NaN
# 97                      NaN       MEH            NaN                JOY
# 98                  DESPAIR       MEH            MEH                NaN
# 99                  DESPAIR       JOY            JOY                MEH
#
#    Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 0                               NaN              NaN                   NaN
# 1                           DESPAIR          DESPAIR               DESPAIR
# 2                               NaN              NaN                   NaN
# 3                               MEH              JOY                   JOY
# 4                           DESPAIR          DESPAIR                   MEH
# ..                              ...              ...                   ...
# 95                          DESPAIR              JOY                   JOY
# 96                              NaN              NaN                   NaN
# 97                              NaN              NaN                   NaN
# 98                          DESPAIR              MEH                   NaN
# 99                          DESPAIR              JOY                   MEH
#
#    Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 0                  NaN                          NaN
# 1                  MEH                      DESPAIR
# 2                  NaN                          NaN
# 3                  MEH                      DESPAIR
# 4                  MEH                      DESPAIR
# ..                 ...                          ...
# 95                 JOY                      DESPAIR
# 96                 NaN                          NaN
# 97                 JOY                      DESPAIR
# 98                 MEH                          NaN
# 99             DESPAIR                      DESPAIR
#
#    Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 0                           NaN             NaN                NaN
# 1                           MEH             MEH            DESPAIR
# 2                           NaN             NaN                NaN
# 3                           JOY             MEH                MEH
# 4                           JOY             MEH            DESPAIR
# ..                          ...             ...                ...
# 95                          JOY             JOY                MEH
# 96                          NaN             NaN                NaN
# 97                          JOY             JOY                NaN
# 98                          MEH             MEH            DESPAIR
# 99                          JOY         DESPAIR            DESPAIR
#
#    Q6 | Heath Bar Q6 | Hershey's Dark Chocolate Q6 | HersheyÕs Milk Chocolate  \
# 0             NaN                           NaN                           NaN
# 1             MEH                           JOY                           JOY
# 2             NaN                           NaN                           NaN
# 3         DESPAIR                           MEH                           MEH
# 4         DESPAIR                           JOY                           MEH
# ..            ...                           ...                           ...
# 95            JOY                           MEH                           MEH
# 96            NaN                           NaN                           NaN
# 97            JOY                           JOY                           JOY
# 98            JOY                           MEH                           MEH
# 99            JOY                           JOY                           JOY
#
#    Q6 | Hershey's Kisses Q6 | Hugs (actual physical hugs)  \
# 0                    NaN                              NaN
# 1                    MEH                          DESPAIR
# 2                    NaN                              NaN
# 3                    MEH                              MEH
# 4                    MEH                          DESPAIR
# ..                   ...                              ...
# 95                   MEH                          DESPAIR
# 96                   NaN                              NaN
# 97                   MEH                              NaN
# 98                   JOY                              MEH
# 99                   JOY                          DESPAIR
#
#    Q6 | Jolly Rancher (bad flavor) Q6 | Jolly Ranchers (good flavor)  \
# 0                              NaN                               NaN
# 1                          DESPAIR                               MEH
# 2                              NaN                               NaN
# 3                              MEH                               MEH
# 4                              MEH                               JOY
# ..                             ...                               ...
# 95                             MEH                               JOY
# 96                             NaN                               NaN
# 97                             MEH                               JOY
# 98                         DESPAIR                           DESPAIR
# 99                         DESPAIR                               JOY
#
#    Q6 | JoyJoy (Mit Iodine!) Q6 | Junior Mints Q6 | Senior Mints  \
# 0                        NaN               NaN               NaN
# 1                    DESPAIR           DESPAIR           DESPAIR
# 2                        NaN               NaN               NaN
# 3                    DESPAIR           DESPAIR           DESPAIR
# 4                        MEH               JOY           DESPAIR
# ..                       ...               ...               ...
# 95                       MEH               JOY           DESPAIR
# 96                       NaN               NaN               NaN
# 97                       NaN           DESPAIR           DESPAIR
# 98                       NaN               JOY               NaN
# 99                   DESPAIR               JOY           DESPAIR
#
#    Q6 | Kale smoothie Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy  \
# 0                 NaN                     NaN          NaN             NaN
# 1             DESPAIR                 DESPAIR          JOY         DESPAIR
# 2                 NaN                     NaN          NaN             NaN
# 3             DESPAIR                     MEH          MEH             JOY
# 4             DESPAIR                     JOY          JOY             JOY
# ..                ...                     ...          ...             ...
# 95            DESPAIR                 DESPAIR          MEH             JOY
# 96                NaN                     NaN          NaN             NaN
# 97                JOY                     NaN          JOY             JOY
# 98            DESPAIR                     JOY          JOY         DESPAIR
# 99            DESPAIR                     JOY          JOY             JOY
#
#    Q6 | LemonHeads Q6 | Licorice (not black) Q6 | Licorice (yes black)  \
# 0              NaN                       NaN                       NaN
# 1              MEH                       MEH                       JOY
# 2              NaN                       NaN                       NaN
# 3              JOY                       MEH                       JOY
# 4              JOY                       MEH                   DESPAIR
# ..             ...                       ...                       ...
# 95             JOY                       JOY                       JOY
# 96             NaN                       NaN                       NaN
# 97             JOY                       MEH                       JOY
# 98             JOY                       MEH                       MEH
# 99             JOY                       MEH                       MEH
#
#    Q6 | Lindt Truffle Q6 | Lollipops Q6 | Mars Q6 | Maynards  \
# 0                 NaN            NaN       NaN           NaN
# 1                 MEH        DESPAIR   DESPAIR       DESPAIR
# 2                 NaN            NaN       NaN           NaN
# 3                 JOY        DESPAIR       JOY           MEH
# 4                 JOY            MEH       MEH       DESPAIR
# ..                ...            ...       ...           ...
# 95                JOY            JOY       JOY           JOY
# 96                NaN            NaN       NaN           NaN
# 97                NaN            NaN       NaN           NaN
# 98                MEH            MEH       MEH           NaN
# 99                JOY            JOY       JOY           NaN
#
#    Q6 | Mike and Ike Q6 | Milk Duds Q6 | Milky Way Q6 | Regular M&Ms  \
# 0                NaN            NaN            NaN               NaN
# 1                MEH            MEH            JOY               JOY
# 2                NaN            NaN            NaN               NaN
# 3                MEH        DESPAIR            JOY               MEH
# 4                MEH            MEH            JOY               JOY
# ..               ...            ...            ...               ...
# 95               JOY            JOY            JOY               MEH
# 96               NaN            NaN            NaN               NaN
# 97               JOY            JOY            MEH               JOY
# 98               MEH        DESPAIR            MEH               JOY
# 99           DESPAIR            JOY            JOY               JOY
#
#    Q6 | Peanut M&MÕs Q6 | Blue M&M's Q6 | Red M&M's Q6 | Green Party M&M's  \
# 0                NaN             NaN            NaN                    NaN
# 1                MEH             JOY            JOY                    JOY
# 2                NaN             NaN            NaN                    NaN
# 3                JOY             MEH            MEH                    MEH
# 4                JOY             JOY            JOY                    JOY
# ..               ...             ...            ...                    ...
# 95               JOY             MEH            MEH                    MEH
# 96               NaN             NaN            NaN                    NaN
# 97               JOY             JOY            JOY                    JOY
# 98               JOY             JOY            JOY                    NaN
# 99               JOY             JOY            JOY                    JOY
#
#    Q6 | Independent M&M's Q6 | Abstained from M&M'ing. Q6 | Minibags of chips  \
# 0                     NaN                          NaN                    NaN
# 1                     JOY                      DESPAIR                DESPAIR
# 2                     NaN                          NaN                    NaN
# 3                     MEH                          MEH                DESPAIR
# 4                     JOY                          MEH                DESPAIR
# ..                    ...                          ...                    ...
# 95                    MEH                          MEH                DESPAIR
# 96                    NaN                          NaN                    NaN
# 97                    JOY                          MEH                    JOY
# 98                    NaN                          NaN                    JOY
# 99                    JOY                          MEH                DESPAIR
#
#    Q6 | Mint Kisses Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers  \
# 0               NaN              NaN              NaN               NaN
# 1               MEH          DESPAIR          DESPAIR           DESPAIR
# 2               NaN              NaN              NaN               NaN
# 3           DESPAIR              MEH              MEH           DESPAIR
# 4               JOY              JOY              MEH           DESPAIR
# ..              ...              ...              ...               ...
# 95              JOY              JOY              JOY               MEH
# 96              NaN              NaN              NaN               NaN
# 97              NaN              NaN              NaN               NaN
# 98              JOY              NaN              JOY           DESPAIR
# 99              JOY          DESPAIR              JOY               JOY
#
#    Q6 | Nerds Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 0         NaN                NaN               NaN        NaN          NaN
# 1     DESPAIR                JOY           DESPAIR    DESPAIR      DESPAIR
# 2         NaN                NaN               NaN        NaN          NaN
# 3         MEH                MEH               MEH    DESPAIR      DESPAIR
# 4         JOY                JOY               JOY        MEH      DESPAIR
# ..        ...                ...               ...        ...          ...
# 95        JOY                JOY               JOY        JOY      DESPAIR
# 96        NaN                NaN               NaN        NaN          NaN
# 97        JOY                NaN               JOY        NaN          NaN
# 98    DESPAIR                MEH           DESPAIR    DESPAIR      DESPAIR
# 99        JOY                JOY               MEH        JOY          MEH
#
#    Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 0             NaN                                                NaN
# 1         DESPAIR                                            DESPAIR
# 2             NaN                                                NaN
# 3         DESPAIR                                            DESPAIR
# 4             JOY                                            DESPAIR
# ..            ...                                                ...
# 95            JOY                                            DESPAIR
# 96            NaN                                                NaN
# 97            NaN                                            DESPAIR
# 98        DESPAIR                                                NaN
# 99            JOY                                            DESPAIR
#
#    Q6 | ReeseÕs Peanut Butter Cups Q6 | Reese's Pieces  \
# 0                              NaN                 NaN
# 1                              JOY                 JOY
# 2                              NaN                 NaN
# 3                              JOY                 MEH
# 4                              JOY                 JOY
# ..                             ...                 ...
# 95                             JOY                 JOY
# 96                             NaN                 NaN
# 97                             JOY             DESPAIR
# 98                             JOY                 JOY
# 99                             JOY                 JOY
#
#    Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 0                      NaN        NaN
# 1                  DESPAIR        JOY
# 2                      NaN        NaN
# 3                      MEH        MEH
# 4                      MEH        JOY
# ..                     ...        ...
# 95                     JOY        JOY
# 96                     NaN        NaN
# 97                     NaN        NaN
# 98                     NaN        JOY
# 99                     NaN        JOY
#
#    Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 0                                                 NaN             NaN
# 1                                             DESPAIR         DESPAIR
# 2                                                 NaN             NaN
# 3                                             DESPAIR         DESPAIR
# 4                                                 NaN             JOY
# ..                                                ...             ...
# 95                                                JOY             JOY
# 96                                                NaN             NaN
# 97                                                NaN             JOY
# 98                                                NaN             MEH
# 99                                            DESPAIR             JOY
#
#    Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 0                       NaN                          NaN           NaN
# 1                   DESPAIR                      DESPAIR           MEH
# 2                       NaN                          NaN           NaN
# 3                   DESPAIR                          MEH           JOY
# 4                       JOY                      DESPAIR           NaN
# ..                      ...                          ...           ...
# 95                      JOY                          MEH           JOY
# 96                      NaN                          NaN           NaN
# 97                  DESPAIR                          NaN           JOY
# 98                  DESPAIR                          MEH           JOY
# 99                      JOY                          NaN           JOY
#
#    Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 0                                                NaN               NaN
# 1                                            DESPAIR           DESPAIR
# 2                                                NaN               NaN
# 3                                                MEH           DESPAIR
# 4                                                MEH           DESPAIR
# ..                                               ...               ...
# 95                                               JOY           DESPAIR
# 96                                               NaN               NaN
# 97                                               JOY               NaN
# 98                                               JOY               NaN
# 99                                               JOY           DESPAIR
#
#    Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 0             NaN              NaN               NaN
# 1             MEH          DESPAIR               MEH
# 2             NaN              NaN               NaN
# 3             MEH              MEH               JOY
# 4             JOY              JOY               MEH
# ..            ...              ...               ...
# 95            JOY              JOY               JOY
# 96            NaN              NaN               NaN
# 97            JOY              JOY               NaN
# 98            JOY          DESPAIR               JOY
# 99            JOY              JOY               JOY
#
#    Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 0                                   NaN         NaN           NaN
# 1                               DESPAIR     DESPAIR       DESPAIR
# 2                                   NaN         NaN           NaN
# 3                                   MEH         JOY           MEH
# 4                               DESPAIR         MEH       DESPAIR
# ..                                  ...         ...           ...
# 95                                  JOY         MEH           MEH
# 96                                  NaN         NaN           NaN
# 97                                  NaN         NaN           NaN
# 98                                  NaN         JOY       DESPAIR
# 99                                  MEH         MEH           JOY
#
#    Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 0                                              NaN                   NaN
# 1                                          DESPAIR                   JOY
# 2                                              NaN                   NaN
# 3                                          DESPAIR               DESPAIR
# 4                                          DESPAIR                   JOY
# ..                                             ...                   ...
# 95                                             MEH                   MEH
# 96                                             NaN                   NaN
# 97                                             JOY               DESPAIR
# 98                                         DESPAIR                   MEH
# 99                                         DESPAIR                   JOY
#
#    Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 0                                NaN            NaN       NaN
# 1                                JOY        DESPAIR       JOY
# 2                                NaN            NaN       NaN
# 3                                JOY            MEH       JOY
# 4                                JOY        DESPAIR       JOY
# ..                               ...            ...       ...
# 95                               JOY        DESPAIR       JOY
# 96                               NaN            NaN       NaN
# 97                               NaN            NaN       JOY
# 98                               MEH            MEH       JOY
# 99                               JOY        DESPAIR       JOY
#
#    Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 0                                                 NaN
# 1                                             DESPAIR
# 2                                                 NaN
# 3                                             DESPAIR
# 4                                                 MEH
# ..                                                ...
# 95                                            DESPAIR
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                            DESPAIR
#
#    Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 0           NaN                       NaN              NaN
# 1       DESPAIR                   DESPAIR          DESPAIR
# 2           NaN                       NaN              NaN
# 3           JOY                       JOY          DESPAIR
# 4           JOY                       JOY          DESPAIR
# ..          ...                       ...              ...
# 95          JOY                       JOY          DESPAIR
# 96          NaN                       NaN              NaN
# 97          NaN                       NaN              NaN
# 98          NaN                       JOY              NaN
# 99          JOY                       JOY          DESPAIR
#
#    Q6 | Whole Wheat anything Q6 | York Peppermint Patties  \
# 0                        NaN                          NaN
# 1                    DESPAIR                      DESPAIR
# 2                        NaN                          NaN
# 3                    DESPAIR                      DESPAIR
# 4                    DESPAIR                          JOY
# ..                       ...                          ...
# 95                   DESPAIR                          JOY
# 96                       NaN                          NaN
# 97                       NaN                      DESPAIR
# 98                       NaN                          JOY
# 99                   DESPAIR                          JOY
#
#                                         Q7: JOY OTHER Q8: DESPAIR OTHER  \
# 0                                                 NaN               NaN
# 1                                              Mounds               NaN
# 2                                                 NaN               NaN
# 3   Reese's crispy crunchy bars, 5th avenue bars, ...               NaN
# 4                                                 NaN               NaN
# ..                                                ...               ...
# 95                                                NaN               NaN
# 96                                                NaN               NaN
# 97                                                NaN               NaN
# 98                                                NaN               NaN
# 99                                                NaN               NaN
#
#                                    Q9: OTHER COMMENTS      Q10: DRESS  \
# 0                                                 NaN             NaN
# 1   Bottom line is Twix is really the only candy w...  White and gold
# 2                                                 NaN             NaN
# 3                              Raisins can go to hell  White and gold
# 4                                                 NaN  White and gold
# ..                                                ...             ...
# 95                                                NaN  White and gold
# 96                                                NaN             NaN
# 97                                                NaN  White and gold
# 98                                                NaN  White and gold
# 99                                                NaN  White and gold
#
#    Unnamed: 113 Q11: DAY  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# 0           NaN      NaN                      NaN                   NaN
# 1           NaN   Sunday                      NaN                   1.0
# 2           NaN      NaN                      NaN                   NaN
# 3           NaN   Sunday                      NaN                   1.0
# 4           NaN   Friday                      NaN                   1.0
# ..          ...      ...                      ...                   ...
# 95          NaN   Sunday                      NaN                   1.0
# 96          NaN      NaN                      NaN                   NaN
# 97          NaN   Sunday                      NaN                   1.0
# 98          NaN   Friday                      NaN                   1.0
# 99          NaN   Sunday                      NaN                   1.0
#
#     Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 0                 NaN                 NaN                      NaN
# 1                 NaN                 NaN                 (84, 25)
# 2                 NaN                 NaN                      NaN
# 3                 NaN                 NaN                 (75, 23)
# 4                 NaN                 NaN                 (70, 10)
# ..                ...                 ...                      ...
# 95                NaN                 NaN                 (82, 28)
# 96                NaN                 NaN                      NaN
# 97                NaN                 NaN                 (76, 29)
# 98                NaN                 NaN                 (75, 11)
# 99                NaN                 NaN                 (78, 26)
#
# [100 rows x 120 columns]

# %%
# Derive item as new field to contain candy name when feeling is JOY

df_candy_hier['item_joy'] = np.where(df_candy_hier['Q6 | 100 Grand Bar'] == 'JOY', '100 Grand Bar',
                   np.where(df_candy_hier['Q6 | Any full-sized candy bar'] == 'JOY', 'Any full-sized candy bar',
                   np.where(df_candy_hier['Q6 | Black Jacks'] == 'JOY', 'Black Jacks',
                   np.where(df_candy_hier['Q6 | Bonkers (the candy)'] == 'JOY', 'Bonkers (the candy)',
                   np.where(df_candy_hier['Q6 | Bonkers (the board game)'] == 'JOY', 'Bonkers (the board game)',
                   np.where(df_candy_hier['Q6 | Bottle Caps'] == 'JOY', 'Bottle Caps',
                   np.where(df_candy_hier["Q6 | Box'o'Raisins"] == 'JOY', "Box'o'Raisins",
                   np.where(df_candy_hier["Q6 | Broken glow stick"] == 'JOY', "Broken glow stick",
                   np.where(df_candy_hier["Q6 | Butterfinger"] == 'JOY', "Butterfinger",
                   np.where(df_candy_hier["Q6 | Cadbury Creme Eggs"] == 'JOY', "Cadbury Creme Eggs",
                   np.where(df_candy_hier["Q6 | Candy Corn"] == 'JOY', "Candy Corn",
                   np.where(df_candy_hier["Q6 | Candy that is clearly just the stuff given out for free at restaurants"] == 'JOY', "Candy that is clearly just the stuff given out for free at restaurants",
                   np.where(df_candy_hier["Q6 | Caramellos"] == 'JOY', "Caramellos",
                   np.where(df_candy_hier["Q6 | Cash, or other forms of legal tender"] == 'JOY', "Cash, or other forms of legal tender",
                   np.where(df_candy_hier["Q6 | Chardonnay"] == 'JOY', "Chardonnay",
                   np.where(df_candy_hier["Q6 | Chick-o-Sticks (we donÕt know what that is)"] == 'JOY', "Chick-o-Sticks (we donÕt know what that is)",
                   np.where(df_candy_hier["Q6 | Chiclets"] == 'JOY', "Chiclets",
                   np.where(df_candy_hier["Q6 | Coffee Crisp"] == 'JOY', "Coffee Crisp",
                   np.where(df_candy_hier["Q6 | Creepy Religious comics/Chick Tracts"] == 'JOY', "Creepy Religious comics/Chick Tracts",
                   np.where(df_candy_hier["Q6 | Dental paraphenalia"] == 'JOY', "Dental paraphenalia",
                   np.where(df_candy_hier["Q6 | Dots"] == 'JOY', "Dots",
                   np.where(df_candy_hier["Q6 | Dove Bars"] == 'JOY', "Dove Bars",
                   np.where(df_candy_hier["Q6 | Fuzzy Peaches"] == 'JOY', "Fuzzy Peaches",
                   np.where(df_candy_hier["Q6 | Generic Brand Acetaminophen"] == 'JOY', "Generic Brand Acetaminophen",
                   np.where(df_candy_hier["Q6 | Glow sticks"] == 'JOY', "Glow sticks",
                   np.where(df_candy_hier["Q6 | Goo Goo Clusters"] == 'JOY', "Goo Goo Clusters",
                   np.where(df_candy_hier["Q6 | Good N' Plenty"] == 'JOY', "Good N' Plenty",
                   np.where(df_candy_hier["Q6 | Gum from baseball cards"] == 'JOY', "Gum from baseball cards",
                   np.where(df_candy_hier["Q6 | Gummy Bears straight up"] == 'JOY', "Gummy Bears straight up",
                   np.where(df_candy_hier["Q6 | Hard Candy"] == 'JOY', "Hard Candy",
                   np.where(df_candy_hier["Q6 | Healthy Fruit"] == 'JOY', "Healthy Fruit",
                   np.where(df_candy_hier["Q6 | Heath Bar"] == 'JOY', "Heath Bar",
                   np.where(df_candy_hier["Q6 | Hershey's Dark Chocolate"] == 'JOY', "Hershey's Dark Chocolate",
                   np.where(df_candy_hier["Q6 | HersheyÕs Milk Chocolate"] == 'JOY', "HersheyÕs Milk Chocolate",
                   np.where(df_candy_hier["Q6 | Hershey's Kisses"] == 'JOY', "Hershey's Kisses",
                   np.where(df_candy_hier["Q6 | Hugs (actual physical hugs)"] == 'JOY', "Hugs (actual physical hugs)",
                   np.where(df_candy_hier["Q6 | Jolly Rancher (bad flavor)"] == 'JOY', "Jolly Rancher (bad flavor)",
                   np.where(df_candy_hier["Q6 | Jolly Ranchers (good flavor)"] == 'JOY', "Jolly Ranchers (good flavor)",
                   np.where(df_candy_hier["Q6 | JoyJoy (Mit Iodine!)"] == 'JOY', "JoyJoy (Mit Iodine!)",
                   np.where(df_candy_hier["Q6 | Junior Mints"] == 'JOY', "Junior Mints",
                   np.where(df_candy_hier["Q6 | Senior Mints"] == 'JOY', "Senior Mints",
                   np.where(df_candy_hier["Q6 | Kale smoothie"] == 'JOY', "Kale smoothie",
                   np.where(df_candy_hier["Q6 | Kinder Happy Hippo"] == 'JOY', "Kinder Happy Hippo",
                   np.where(df_candy_hier["Q6 | Kit Kat"] == 'JOY', "Kit Kat",
                   np.where(df_candy_hier["Q6 | LaffyTaffy"] == 'JOY', "LaffyTaffy",
                            'NA')))))))))))))))))))))))))))))))))))))))))))))

# %%
# We can now use item column to merge df_candy and df_candy_hier datasets
df_candy_hier.merge(df_candy,left_on='item_joy', right_on='ITEM', how='left')
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0        90258773            NaN        NaN     NaN         NaN
# 1        90272821             No       Male      44        USA
# 2        90272829            NaN       Male      49         USA
# 3        90272840             No       Male      40          us
# 4        90272841             No       Male      23         usa
# ...           ...            ...        ...     ...         ...
# 2455     90314359             No       Male      24         USA
# 2456     90314580             No     Female      33         USA
# 2457     90314634             No     Female      26        USA
# 2458     90314658             No       Male      58         Usa
# 2459     90314802             No     Female      66         usa
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                                 NaN                NaN
# 1                                  NM                MEH
# 2                            Virginia                NaN
# 3                                  or                MEH
# 4                            exton pa                JOY
# ...                               ...                ...
# 2455                               MD                JOY
# 2456                         New York                MEH
# 2457                        Tennessee                MEH
# 2458                   North Carolina                NaN
# 2459                     Pennsylvania            DESPAIR
#
#      Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                   NaN
# 1                                               DESPAIR
# 2                                                   NaN
# 3                                               DESPAIR
# 4                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                            DESPAIR
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 0                              NaN              NaN                      NaN
# 1                              JOY              MEH                  DESPAIR
# 2                              NaN              NaN                      NaN
# 3                              JOY              MEH                      MEH
# 4                              JOY          DESPAIR                      MEH
# ...                            ...              ...                      ...
# 2455                           MEH          DESPAIR                  DESPAIR
# 2456                           JOY              NaN                      NaN
# 2457                           JOY          DESPAIR                      MEH
# 2458                           NaN              NaN                      NaN
# 2459                           JOY          DESPAIR                  DESPAIR
#
#      Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 0                              NaN              NaN                NaN
# 1                          DESPAIR          DESPAIR            DESPAIR
# 2                              NaN              NaN                NaN
# 3                          DESPAIR              MEH            DESPAIR
# 4                          DESPAIR              MEH            DESPAIR
# ...                            ...              ...                ...
# 2455                           MEH              MEH            DESPAIR
# 2456                           NaN              NaN            DESPAIR
# 2457                           JOY          DESPAIR                MEH
# 2458                           NaN              NaN                NaN
# 2459                       DESPAIR          DESPAIR                MEH
#
#      Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 0                       NaN               NaN                     NaN
# 1                   DESPAIR           DESPAIR                     MEH
# 2                       NaN               NaN                     NaN
# 3                   DESPAIR               MEH                     MEH
# 4                   DESPAIR               MEH                     MEH
# ...                     ...               ...                     ...
# 2455                DESPAIR               MEH                 DESPAIR
# 2456                DESPAIR               JOY                     JOY
# 2457                    MEH           DESPAIR                     JOY
# 2458                    NaN               NaN                     NaN
# 2459                DESPAIR               JOY                     MEH
#
#      Q6 | Candy Corn  \
# 0                NaN
# 1                MEH
# 2                NaN
# 3            DESPAIR
# 4            DESPAIR
# ...              ...
# 2455         DESPAIR
# 2456             JOY
# 2457         DESPAIR
# 2458             NaN
# 2459             MEH
#
#      Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 0                                                   NaN
# 1                                               DESPAIR
# 2                                                   NaN
# 3                                               DESPAIR
# 4                                               DESPAIR
# ...                                                 ...
# 2455                                            DESPAIR
# 2456                                            DESPAIR
# 2457                                                MEH
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Caramellos Q6 | Cash, or other forms of legal tender  \
# 0                NaN                                       NaN
# 1                MEH                                       JOY
# 2                NaN                                       NaN
# 3                MEH                                       JOY
# 4                JOY                                       MEH
# ...              ...                                       ...
# 2455             JOY                                       JOY
# 2456             JOY                                       JOY
# 2457         DESPAIR                                       JOY
# 2458             NaN                                       NaN
# 2459             MEH                                       JOY
#
#      Q6 | Chardonnay Q6 | Chick-o-Sticks (we donÕt know what that is)  \
# 0                NaN                                              NaN
# 1                MEH                                          DESPAIR
# 2                NaN                                              NaN
# 3                MEH                                              JOY
# 4                JOY                                          DESPAIR
# ...              ...                                              ...
# 2455             JOY                                              MEH
# 2456             JOY                                              JOY
# 2457             JOY                                              MEH
# 2458             NaN                                              NaN
# 2459             JOY                                          DESPAIR
#
#      Q6 | Chiclets Q6 | Coffee Crisp  \
# 0              NaN               NaN
# 1          DESPAIR           DESPAIR
# 2              NaN               NaN
# 3              MEH           DESPAIR
# 4          DESPAIR               MEH
# ...            ...               ...
# 2455           JOY               JOY
# 2456       DESPAIR               NaN
# 2457           MEH           DESPAIR
# 2458           NaN               NaN
# 2459           MEH           DESPAIR
#
#      Q6 | Creepy Religious comics/Chick Tracts Q6 | Dental paraphenalia  \
# 0                                          NaN                      NaN
# 1                                      DESPAIR                  DESPAIR
# 2                                          NaN                      NaN
# 3                                      DESPAIR                  DESPAIR
# 4                                      DESPAIR                  DESPAIR
# ...                                        ...                      ...
# 2455                                   DESPAIR                      MEH
# 2456                                   DESPAIR                  DESPAIR
# 2457                                   DESPAIR                  DESPAIR
# 2458                                       NaN                      NaN
# 2459                                   DESPAIR                  DESPAIR
#
#      Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 0          NaN            NaN                NaN
# 1          MEH            JOY            DESPAIR
# 2          NaN            NaN                NaN
# 3          JOY            JOY                MEH
# 4          MEH            JOY            DESPAIR
# ...        ...            ...                ...
# 2455   DESPAIR            JOY                MEH
# 2456   DESPAIR            MEH                NaN
# 2457       MEH            JOY                MEH
# 2458       NaN            NaN                NaN
# 2459       JOY            JOY                MEH
#
#      Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 0                                 NaN              NaN                   NaN
# 1                             DESPAIR          DESPAIR               DESPAIR
# 2                                 NaN              NaN                   NaN
# 3                                 MEH              JOY                   JOY
# 4                             DESPAIR          DESPAIR                   MEH
# ...                               ...              ...                   ...
# 2455                              JOY          DESPAIR                   JOY
# 2456                              MEH          DESPAIR                   NaN
# 2457                              JOY              JOY               DESPAIR
# 2458                              NaN              NaN                   NaN
# 2459                          DESPAIR              MEH               DESPAIR
#
#      Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 0                    NaN                          NaN
# 1                    MEH                      DESPAIR
# 2                    NaN                          NaN
# 3                    MEH                      DESPAIR
# 4                    MEH                      DESPAIR
# ...                  ...                          ...
# 2455                 JOY                          JOY
# 2456             DESPAIR                      DESPAIR
# 2457             DESPAIR                      DESPAIR
# 2458                 NaN                          NaN
# 2459                 JOY                      DESPAIR
#
#      Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 0                             NaN             NaN                NaN
# 1                             MEH             MEH            DESPAIR
# 2                             NaN             NaN                NaN
# 3                             JOY             MEH                MEH
# 4                             JOY             MEH            DESPAIR
# ...                           ...             ...                ...
# 2455                          MEH         DESPAIR                MEH
# 2456                          MEH             MEH            DESPAIR
# 2457                          MEH             MEH            DESPAIR
# 2458                          NaN             NaN                NaN
# 2459                          MEH         DESPAIR            DESPAIR
#
#      Q6 | Heath Bar Q6 | Hershey's Dark Chocolate  \
# 0               NaN                           NaN
# 1               MEH                           JOY
# 2               NaN                           NaN
# 3           DESPAIR                           MEH
# 4           DESPAIR                           JOY
# ...             ...                           ...
# 2455        DESPAIR                           JOY
# 2456            JOY                           MEH
# 2457            MEH                           JOY
# 2458            NaN                           NaN
# 2459        DESPAIR                           JOY
#
#      Q6 | HersheyÕs Milk Chocolate Q6 | Hershey's Kisses  \
# 0                              NaN                   NaN
# 1                              JOY                   MEH
# 2                              NaN                   NaN
# 3                              MEH                   MEH
# 4                              MEH                   MEH
# ...                            ...                   ...
# 2455                           MEH                   MEH
# 2456                           JOY                   MEH
# 2457                           JOY                   JOY
# 2458                           NaN                   NaN
# 2459                           JOY                   JOY
#
#      Q6 | Hugs (actual physical hugs) Q6 | Jolly Rancher (bad flavor)  \
# 0                                 NaN                             NaN
# 1                             DESPAIR                         DESPAIR
# 2                                 NaN                             NaN
# 3                                 MEH                             MEH
# 4                             DESPAIR                             MEH
# ...                               ...                             ...
# 2455                              JOY                             MEH
# 2456                          DESPAIR                             MEH
# 2457                              MEH                         DESPAIR
# 2458                              NaN                             NaN
# 2459                          DESPAIR                         DESPAIR
#
#      Q6 | Jolly Ranchers (good flavor) Q6 | JoyJoy (Mit Iodine!)  \
# 0                                  NaN                       NaN
# 1                                  MEH                   DESPAIR
# 2                                  NaN                       NaN
# 3                                  MEH                   DESPAIR
# 4                                  JOY                       MEH
# ...                                ...                       ...
# 2455                               MEH                       MEH
# 2456                               JOY                       NaN
# 2457                               JOY                   DESPAIR
# 2458                               NaN                       NaN
# 2459                               MEH                   DESPAIR
#
#      Q6 | Junior Mints Q6 | Senior Mints Q6 | Kale smoothie  \
# 0                  NaN               NaN                NaN
# 1              DESPAIR           DESPAIR            DESPAIR
# 2                  NaN               NaN                NaN
# 3              DESPAIR           DESPAIR            DESPAIR
# 4                  JOY           DESPAIR            DESPAIR
# ...                ...               ...                ...
# 2455           DESPAIR           DESPAIR                MEH
# 2456               JOY               NaN            DESPAIR
# 2457               JOY               MEH            DESPAIR
# 2458               NaN               NaN                NaN
# 2459               JOY           DESPAIR            DESPAIR
#
#      Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy Q6 | LemonHeads  \
# 0                        NaN          NaN             NaN             NaN
# 1                    DESPAIR          JOY         DESPAIR             MEH
# 2                        NaN          NaN             NaN             NaN
# 3                        MEH          MEH             JOY             JOY
# 4                        JOY          JOY             JOY             JOY
# ...                      ...          ...             ...             ...
# 2455                     JOY          JOY             MEH             MEH
# 2456                     NaN          JOY         DESPAIR         DESPAIR
# 2457                 DESPAIR      DESPAIR             JOY         DESPAIR
# 2458                     NaN          NaN             NaN             NaN
# 2459                 DESPAIR          MEH         DESPAIR         DESPAIR
#
#      Q6 | Licorice (not black) Q6 | Licorice (yes black) Q6 | Lindt Truffle  \
# 0                          NaN                       NaN                NaN
# 1                          MEH                       JOY                MEH
# 2                          NaN                       NaN                NaN
# 3                          MEH                       JOY                JOY
# 4                          MEH                   DESPAIR                JOY
# ...                        ...                       ...                ...
# 2455                       JOY                   DESPAIR                JOY
# 2456                       MEH                   DESPAIR                MEH
# 2457                       MEH                   DESPAIR                JOY
# 2458                       NaN                       NaN                NaN
# 2459                   DESPAIR                   DESPAIR                JOY
#
#      Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike Q6 | Milk Duds  \
# 0               NaN       NaN           NaN               NaN            NaN
# 1           DESPAIR   DESPAIR       DESPAIR               MEH            MEH
# 2               NaN       NaN           NaN               NaN            NaN
# 3           DESPAIR       JOY           MEH               MEH        DESPAIR
# 4               MEH       MEH       DESPAIR               MEH            MEH
# ...             ...       ...           ...               ...            ...
# 2455        DESPAIR       MEH           MEH               MEH            JOY
# 2456            MEH       NaN           NaN           DESPAIR            MEH
# 2457            MEH       JOY       DESPAIR               MEH            JOY
# 2458            NaN       NaN           NaN               NaN            NaN
# 2459        DESPAIR       JOY       DESPAIR               MEH        DESPAIR
#
#      Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&MÕs Q6 | Blue M&M's  \
# 0               NaN               NaN               NaN             NaN
# 1               JOY               JOY               MEH             JOY
# 2               NaN               NaN               NaN             NaN
# 3               JOY               MEH               JOY             MEH
# 4               JOY               JOY               JOY             JOY
# ...             ...               ...               ...             ...
# 2455            JOY               MEH               JOY             JOY
# 2456            MEH               JOY               JOY             NaN
# 2457            JOY               JOY           DESPAIR             JOY
# 2458            NaN               NaN               NaN             NaN
# 2459            JOY               JOY               JOY             JOY
#
#      Q6 | Red M&M's Q6 | Green Party M&M's Q6 | Independent M&M's  \
# 0               NaN                    NaN                    NaN
# 1               JOY                    JOY                    JOY
# 2               NaN                    NaN                    NaN
# 3               MEH                    MEH                    MEH
# 4               JOY                    JOY                    JOY
# ...             ...                    ...                    ...
# 2455            MEH                    JOY                    JOY
# 2456            NaN                    NaN                    NaN
# 2457            JOY                    JOY                    JOY
# 2458            NaN                    NaN                    NaN
# 2459            JOY                    JOY                DESPAIR
#
#      Q6 | Abstained from M&M'ing. Q6 | Minibags of chips Q6 | Mint Kisses  \
# 0                             NaN                    NaN              NaN
# 1                         DESPAIR                DESPAIR              MEH
# 2                             NaN                    NaN              NaN
# 3                             MEH                DESPAIR          DESPAIR
# 4                             MEH                DESPAIR              JOY
# ...                           ...                    ...              ...
# 2455                          MEH                    MEH              JOY
# 2456                          NaN                    MEH              JOY
# 2457                      DESPAIR                    JOY              JOY
# 2458                          NaN                    NaN              NaN
# 2459                      DESPAIR                    MEH              MEH
#
#      Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers Q6 | Nerds  \
# 0                 NaN              NaN               NaN        NaN
# 1             DESPAIR          DESPAIR           DESPAIR    DESPAIR
# 2                 NaN              NaN               NaN        NaN
# 3                 MEH              MEH           DESPAIR        MEH
# 4                 JOY              MEH           DESPAIR        JOY
# ...               ...              ...               ...        ...
# 2455              JOY              JOY               MEH        MEH
# 2456              NaN              JOY           DESPAIR        JOY
# 2457              JOY          DESPAIR           DESPAIR        MEH
# 2458              NaN              NaN               NaN        NaN
# 2459          DESPAIR              JOY               MEH    DESPAIR
#
#      Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 0                   NaN               NaN        NaN          NaN
# 1                   JOY           DESPAIR    DESPAIR      DESPAIR
# 2                   NaN               NaN        NaN          NaN
# 3                   MEH               MEH    DESPAIR      DESPAIR
# 4                   JOY               JOY        MEH      DESPAIR
# ...                 ...               ...        ...          ...
# 2455                JOY               JOY    DESPAIR      DESPAIR
# 2456                MEH               JOY    DESPAIR      DESPAIR
# 2457            DESPAIR               MEH        MEH          MEH
# 2458                NaN               NaN        NaN          NaN
# 2459                MEH           DESPAIR        MEH      DESPAIR
#
#      Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 0               NaN                                                NaN
# 1           DESPAIR                                            DESPAIR
# 2               NaN                                                NaN
# 3           DESPAIR                                            DESPAIR
# 4               JOY                                            DESPAIR
# ...             ...                                                ...
# 2455            JOY                                                MEH
# 2456            MEH                                            DESPAIR
# 2457            JOY                                                JOY
# 2458            NaN                                                NaN
# 2459        DESPAIR                                            DESPAIR
#
#      Q6 | ReeseÕs Peanut Butter Cups Q6 | Reese's Pieces  \
# 0                                NaN                 NaN
# 1                                JOY                 JOY
# 2                                NaN                 NaN
# 3                                JOY                 MEH
# 4                                JOY                 JOY
# ...                              ...                 ...
# 2455                             JOY                 JOY
# 2456                             JOY                 JOY
# 2457                             JOY                 MEH
# 2458                             NaN                 NaN
# 2459                             MEH             DESPAIR
#
#      Q6 | Reggie Jackson Bar Q6 | Rolos  \
# 0                        NaN        NaN
# 1                    DESPAIR        JOY
# 2                        NaN        NaN
# 3                        MEH        MEH
# 4                        MEH        JOY
# ...                      ...        ...
# 2455                     JOY        JOY
# 2456                     NaN        MEH
# 2457                     MEH        JOY
# 2458                     NaN        NaN
# 2459                 DESPAIR    DESPAIR
#
#      Q6 | Sandwich-sized bags filled with BooBerry Crunch Q6 | Skittles  \
# 0                                                   NaN             NaN
# 1                                               DESPAIR         DESPAIR
# 2                                                   NaN             NaN
# 3                                               DESPAIR         DESPAIR
# 4                                                   NaN             JOY
# ...                                                 ...             ...
# 2455                                                JOY             MEH
# 2456                                            DESPAIR             JOY
# 2457                                            DESPAIR         DESPAIR
# 2458                                                NaN             NaN
# 2459                                            DESPAIR         DESPAIR
#
#      Q6 | Smarties (American) Q6 | Smarties (Commonwealth) Q6 | Snickers  \
# 0                         NaN                          NaN           NaN
# 1                     DESPAIR                      DESPAIR           MEH
# 2                         NaN                          NaN           NaN
# 3                     DESPAIR                          MEH           JOY
# 4                         JOY                      DESPAIR           NaN
# ...                       ...                          ...           ...
# 2455                  DESPAIR                      DESPAIR           JOY
# 2456                  DESPAIR                          NaN           JOY
# 2457                      JOY                          MEH       DESPAIR
# 2458                      NaN                          NaN           NaN
# 2459                      MEH                      DESPAIR           JOY
#
#      Q6 | Sourpatch Kids (i.e. abominations of nature) Q6 | Spotted Dick  \
# 0                                                  NaN               NaN
# 1                                              DESPAIR           DESPAIR
# 2                                                  NaN               NaN
# 3                                                  MEH           DESPAIR
# 4                                                  MEH           DESPAIR
# ...                                                ...               ...
# 2455                                               JOY               JOY
# 2456                                               MEH               NaN
# 2457                                           DESPAIR           DESPAIR
# 2458                                               NaN               NaN
# 2459                                               JOY           DESPAIR
#
#      Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 0               NaN              NaN               NaN
# 1               MEH          DESPAIR               MEH
# 2               NaN              NaN               NaN
# 3               MEH              MEH               JOY
# 4               JOY              JOY               MEH
# ...             ...              ...               ...
# 2455            JOY              MEH               JOY
# 2456            MEH              MEH               MEH
# 2457        DESPAIR              JOY           DESPAIR
# 2458            NaN              NaN               NaN
# 2459            MEH              MEH           DESPAIR
#
#      Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 0                                     NaN         NaN           NaN
# 1                                 DESPAIR     DESPAIR       DESPAIR
# 2                                     NaN         NaN           NaN
# 3                                     MEH         JOY           MEH
# 4                                 DESPAIR         MEH       DESPAIR
# ...                                   ...         ...           ...
# 2455                              DESPAIR         MEH           JOY
# 2456                                  NaN         JOY       DESPAIR
# 2457                              DESPAIR         MEH           MEH
# 2458                                  NaN         NaN           NaN
# 2459                              DESPAIR     DESPAIR       DESPAIR
#
#      Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 0                                                NaN                   NaN
# 1                                            DESPAIR                   JOY
# 2                                                NaN                   NaN
# 3                                            DESPAIR               DESPAIR
# 4                                            DESPAIR                   JOY
# ...                                              ...                   ...
# 2455                                         DESPAIR                   MEH
# 2456                                         DESPAIR                   MEH
# 2457                                         DESPAIR                   JOY
# 2458                                             NaN                   NaN
# 2459                                         DESPAIR                   JOY
#
#      Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 0                                  NaN            NaN       NaN
# 1                                  JOY        DESPAIR       JOY
# 2                                  NaN            NaN       NaN
# 3                                  JOY            MEH       JOY
# 4                                  JOY        DESPAIR       JOY
# ...                                ...            ...       ...
# 2455                               MEH            JOY       JOY
# 2456                               MEH        DESPAIR       JOY
# 2457                               JOY            MEH       MEH
# 2458                               NaN            NaN       NaN
# 2459                               MEH        DESPAIR   DESPAIR
#
#      Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 0                                                   NaN
# 1                                               DESPAIR
# 2                                                   NaN
# 3                                               DESPAIR
# 4                                                   MEH
# ...                                                 ...
# 2455                                                MEH
# 2456                                                NaN
# 2457                                                MEH
# 2458                                                NaN
# 2459                                            DESPAIR
#
#      Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 0             NaN                       NaN              NaN
# 1         DESPAIR                   DESPAIR          DESPAIR
# 2             NaN                       NaN              NaN
# 3             JOY                       JOY          DESPAIR
# 4             JOY                       JOY          DESPAIR
# ...           ...                       ...              ...
# 2455          JOY                   DESPAIR              MEH
# 2456          NaN                       JOY          DESPAIR
# 2457          JOY                       MEH          DESPAIR
# 2458          NaN                       NaN              NaN
# 2459          JOY                   DESPAIR              MEH
#
#      Q6 | Whole Wheat anything Q6 | York Peppermint Patties  \
# 0                          NaN                          NaN
# 1                      DESPAIR                      DESPAIR
# 2                          NaN                          NaN
# 3                      DESPAIR                      DESPAIR
# 4                      DESPAIR                          JOY
# ...                        ...                          ...
# 2455                   DESPAIR                          MEH
# 2456                       MEH                          JOY
# 2457                   DESPAIR                          MEH
# 2458                       NaN                          NaN
# 2459                   DESPAIR                          JOY
#
#                                           Q7: JOY OTHER Q8: DESPAIR OTHER  \
# 0                                                   NaN               NaN
# 1                                                Mounds               NaN
# 2                                                   NaN               NaN
# 3     Reese's crispy crunchy bars, 5th avenue bars, ...               NaN
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 2455                                             Mounds  Fruit Stripe Gum
# 2456                                                NaN            Capers
# 2457  Tiny bottles of maple syrup as given out by Cr...               NaN
# 2458                                                NaN               NaN
# 2459                                                NaN               NaN
#
#                                      Q9: OTHER COMMENTS      Q10: DRESS  \
# 0                                                   NaN             NaN
# 1     Bottom line is Twix is really the only candy w...  White and gold
# 2                                                   NaN             NaN
# 3                                Raisins can go to hell  White and gold
# 4                                                   NaN  White and gold
# ...                                                 ...             ...
# 2455                                                NaN  White and gold
# 2456                                                NaN  Blue and black
# 2457                                                NaN  Blue and black
# 2458                                                NaN             NaN
# 2459  You hit all my chocolate highlights, and broug...  White and gold
#
#      Unnamed: 113 Q11: DAY  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# 0             NaN      NaN                      NaN                   NaN
# 1             NaN   Sunday                      NaN                   1.0
# 2             NaN      NaN                      NaN                   NaN
# 3             NaN   Sunday                      NaN                   1.0
# 4             NaN   Friday                      NaN                   1.0
# ...           ...      ...                      ...                   ...
# 2455          NaN   Friday                      NaN                   NaN
# 2456          NaN   Friday                      NaN                   1.0
# 2457          NaN   Friday                      NaN                   1.0
# 2458          NaN      NaN                      NaN                   NaN
# 2459          NaN   Sunday                      1.0                   NaN
#
#       Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo] Click Coordinates (x, y)  \
# 0                   NaN                 NaN                      NaN
# 1                   NaN                 NaN                 (84, 25)
# 2                   NaN                 NaN                      NaN
# 3                   NaN                 NaN                 (75, 23)
# 4                   NaN                 NaN                 (70, 10)
# ...                 ...                 ...                      ...
# 2455                NaN                 NaN                      NaN
# 2456                NaN                 NaN                 (70, 26)
# 2457                NaN                 NaN                 (67, 35)
# 2458                NaN                 NaN                      NaN
# 2459                NaN                 NaN                 (19, 26)
#
#                       item_joy                      ITEM    JOY  DESPAIR  \
# 0                           NA                       NaN    NaN      NaN
# 1     Any full-sized candy bar  Any full-sized candy bar  828.0     13.0
# 2                           NA                       NaN    NaN      NaN
# 3     Any full-sized candy bar  Any full-sized candy bar  828.0     13.0
# 4                100 Grand Bar             100 Grand Bar  570.0     34.0
# ...                        ...                       ...    ...      ...
# 2455             100 Grand Bar             100 Grand Bar  570.0     34.0
# 2456  Any full-sized candy bar  Any full-sized candy bar  828.0     13.0
# 2457  Any full-sized candy bar  Any full-sized candy bar  828.0     13.0
# 2458                        NA                       NaN    NaN      NaN
# 2459  Any full-sized candy bar  Any full-sized candy bar  828.0     13.0
#
#       NET FEELIES  NET CLOUT  DESPAIR (NEG)
# 0             NaN        NaN            NaN
# 1           815.0   1.936093          -13.0
# 2             NaN        NaN            NaN
# 3           815.0   1.936093          -13.0
# 4           536.0   1.390488          -34.0
# ...           ...        ...            ...
# 2455        536.0   1.390488          -34.0
# 2456        815.0   1.936093          -13.0
# 2457        815.0   1.936093          -13.0
# 2458          NaN        NaN            NaN
# 2459        815.0   1.936093          -13.0
#
# [2460 rows x 127 columns]

# %% [markdown]
# ### Transform 4 (Chapter 8) : Reshape

# %%
# Using reshape to convert data from wide format to long format
df_candy_hier_melt = pd.melt(df_candy_hier, id_vars='Internal ID', value_vars=['Q2: GENDER','Q3: AGE','Q4: COUNTRY','Q5: STATE, PROVINCE, COUNTY, ETC'])

# %%
# check the data
df_candy_hier_melt.head(3000)
# Out:
#       Internal ID    variable value
# 0        90258773  Q2: GENDER   NaN
# 1        90272821  Q2: GENDER  Male
# 2        90272829  Q2: GENDER  Male
# 3        90272840  Q2: GENDER  Male
# 4        90272841  Q2: GENDER  Male
# ...           ...         ...   ...
# 2995     90274485     Q3: AGE    40
# 2996     90274486     Q3: AGE    44
# 2997     90274489     Q3: AGE    50
# 2998     90274490     Q3: AGE    48
# 2999     90274508     Q3: AGE    61
#
# [3000 rows x 3 columns]

# %% [markdown]
# ### Transform 5 (Chapter 10) : Grouping with Functions

# %%
# Group data in candy hier to see how many observations we have by state, province, county
df_candy_hier.groupby(by=["Q5: STATE, PROVINCE, COUNTY, ETC"], dropna=False).count()
# Out:
#                                   Internal ID  Q1: GOING OUT?  Q2: GENDER  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                           1               1           1
# 48                                          1               1           1
# A                                           1               1           1
# AB                                          3               2           3
# AZ                                          7               7           7
# ...                                       ...             ...         ...
# wyoming                                     1               1           1
# yukon                                       1               1           1
# |NC                                         1               1           1
# ¯rb¾k                                       1               1           1
# NaN                                       100              74          66
#
#                                   Q3: AGE  Q4: COUNTRY  Q6 | 100 Grand Bar  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                       1            1                   0
# 48                                      0            0                   0
# A                                       1            1                   1
# AB                                      3            3                   0
# AZ                                      7            7                   5
# ...                                   ...          ...                 ...
# wyoming                                 1            1                   1
# yukon                                   1            1                   1
# |NC                                     1            1                   1
# ¯rb¾k                                   1            1                   1
# NaN                                    38           41                  37
#
#                                   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                                 0
# 48                                                                                0
# A                                                                                 1
# AB                                                                                1
# AZ                                                                                5
# ...                                                                             ...
# wyoming                                                                           1
# yukon                                                                             1
# |NC                                                                               1
# ¯rb¾k                                                                             1
# NaN                                                                              38
#
#                                   Q6 | Any full-sized candy bar  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                             0
# 48                                                            0
# A                                                             1
# AB                                                            1
# AZ                                                            5
# ...                                                         ...
# wyoming                                                       1
# yukon                                                         1
# |NC                                                           1
# ¯rb¾k                                                         1
# NaN                                                          41
#
#                                   Q6 | Black Jacks  Q6 | Bonkers (the candy)  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                0                         0
# 48                                               0                         0
# A                                                1                         1
# AB                                               0                         1
# AZ                                               5                         5
# ...                                            ...                       ...
# wyoming                                          1                         1
# yukon                                            0                         0
# |NC                                              1                         1
# ¯rb¾k                                            1                         1
# NaN                                             30                        28
#
#                                   Q6 | Bonkers (the board game)  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                             0
# 48                                                            0
# A                                                             1
# AB                                                            0
# AZ                                                            5
# ...                                                         ...
# wyoming                                                       1
# yukon                                                         0
# |NC                                                           1
# ¯rb¾k                                                         1
# NaN                                                          29
#
#                                   Q6 | Bottle Caps  Q6 | Box'o'Raisins  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                0                   0
# 48                                               0                   0
# A                                                1                   1
# AB                                               1                   0
# AZ                                               5                   5
# ...                                            ...                 ...
# wyoming                                          1                   1
# yukon                                            1                   1
# |NC                                              1                   1
# ¯rb¾k                                            1                   1
# NaN                                             37                  39
#
#                                   Q6 | Broken glow stick  Q6 | Butterfinger  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                      0                  0
# 48                                                     0                  0
# A                                                      1                  1
# AB                                                     1                  1
# AZ                                                     5                  4
# ...                                                  ...                ...
# wyoming                                                1                  1
# yukon                                                  1                  1
# |NC                                                    1                  1
# ¯rb¾k                                                  1                  1
# NaN                                                   40                 41
#
#                                   Q6 | Cadbury Creme Eggs  Q6 | Candy Corn  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                       0                0
# 48                                                      0                0
# A                                                       1                1
# AB                                                      1                1
# AZ                                                      5                5
# ...                                                   ...              ...
# wyoming                                                 1                1
# yukon                                                   1                1
# |NC                                                     1                1
# ¯rb¾k                                                   1                1
# NaN                                                    41               40
#
#                                   Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                                 0
# 48                                                                                0
# A                                                                                 1
# AB                                                                                1
# AZ                                                                                5
# ...                                                                             ...
# wyoming                                                                           1
# yukon                                                                             1
# |NC                                                                               1
# ¯rb¾k                                                                             1
# NaN                                                                              39
#
#                                   Q6 | Caramellos  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                               0
# 48                                              0
# A                                               1
# AB                                              0
# AZ                                              5
# ...                                           ...
# wyoming                                         1
# yukon                                           1
# |NC                                             1
# ¯rb¾k                                           1
# NaN                                            38
#
#                                   Q6 | Cash, or other forms of legal tender  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                         0
# 48                                                                        0
# A                                                                         1
# AB                                                                        1
# AZ                                                                        5
# ...                                                                     ...
# wyoming                                                                   1
# yukon                                                                     1
# |NC                                                                       1
# ¯rb¾k                                                                     1
# NaN                                                                      40
#
#                                   Q6 | Chardonnay  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                               0
# 48                                              0
# A                                               1
# AB                                              1
# AZ                                              5
# ...                                           ...
# wyoming                                         1
# yukon                                           1
# |NC                                             1
# ¯rb¾k                                           1
# NaN                                            38
#
#                                   Q6 | Chick-o-Sticks (we donÕt know what that is)  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                                0
# 48                                                                               0
# A                                                                                1
# AB                                                                               0
# AZ                                                                               5
# ...                                                                            ...
# wyoming                                                                          1
# yukon                                                                            0
# |NC                                                                              1
# ¯rb¾k                                                                            1
# NaN                                                                             32
#
#                                   Q6 | Chiclets  Q6 | Coffee Crisp  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                             0                  0
# 48                                            0                  0
# A                                             1                  1
# AB                                            1                  1
# AZ                                            5                  5
# ...                                         ...                ...
# wyoming                                       1                  1
# yukon                                         1                  1
# |NC                                           1                  1
# ¯rb¾k                                         1                  1
# NaN                                          41                 37
#
#                                   Q6 | Creepy Religious comics/Chick Tracts  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                         0
# 48                                                                        0
# A                                                                         1
# AB                                                                        1
# AZ                                                                        5
# ...                                                                     ...
# wyoming                                                                   1
# yukon                                                                     1
# |NC                                                                       1
# ¯rb¾k                                                                     1
# NaN                                                                      41
#
#                                   Q6 | Dental paraphenalia  Q6 | Dots  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                        0          0
# 48                                                       0          0
# A                                                        1          1
# AB                                                       1          1
# AZ                                                       5          5
# ...                                                    ...        ...
# wyoming                                                  1          1
# yukon                                                    1          1
# |NC                                                      1          1
# ¯rb¾k                                                    1          1
# NaN                                                     41         37
#
#                                   Q6 | Dove Bars  Q6 | Fuzzy Peaches  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                              0                   0
# 48                                             0                   0
# A                                              1                   1
# AB                                             1                   1
# AZ                                             5                   5
# ...                                          ...                 ...
# wyoming                                        1                   1
# yukon                                          1                   1
# |NC                                            1                   1
# ¯rb¾k                                          1                   1
# NaN                                           38                  35
#
#                                   Q6 | Generic Brand Acetaminophen  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                0
# 48                                                               0
# A                                                                1
# AB                                                               1
# AZ                                                               5
# ...                                                            ...
# wyoming                                                          1
# yukon                                                            1
# |NC                                                              1
# ¯rb¾k                                                            1
# NaN                                                             39
#
#                                   Q6 | Glow sticks  Q6 | Goo Goo Clusters  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                0                      0
# 48                                               0                      0
# A                                                1                      1
# AB                                               1                      0
# AZ                                               5                      5
# ...                                            ...                    ...
# wyoming                                          1                      1
# yukon                                            1                      0
# |NC                                              1                      1
# ¯rb¾k                                            1                      1
# NaN                                             41                     34
#
#                                   Q6 | Good N' Plenty  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                   0
# 48                                                  0
# A                                                   1
# AB                                                  0
# AZ                                                  5
# ...                                               ...
# wyoming                                             1
# yukon                                               0
# |NC                                                 1
# ¯rb¾k                                               1
# NaN                                                38
#
#                                   Q6 | Gum from baseball cards  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                            0
# 48                                                           0
# A                                                            1
# AB                                                           1
# AZ                                                           5
# ...                                                        ...
# wyoming                                                      1
# yukon                                                        1
# |NC                                                          1
# ¯rb¾k                                                        1
# NaN                                                         40
#
#                                   Q6 | Gummy Bears straight up  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                            0
# 48                                                           0
# A                                                            1
# AB                                                           1
# AZ                                                           5
# ...                                                        ...
# wyoming                                                      1
# yukon                                                        1
# |NC                                                          1
# ¯rb¾k                                                        1
# NaN                                                         40
#
#                                   Q6 | Hard Candy  Q6 | Healthy Fruit  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                               0                   0
# 48                                              0                   0
# A                                               1                   1
# AB                                              1                   1
# AZ                                              5                   5
# ...                                           ...                 ...
# wyoming                                         1                   1
# yukon                                           1                   1
# |NC                                             1                   1
# ¯rb¾k                                           1                   1
# NaN                                            39                  41
#
#                                   Q6 | Heath Bar  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                              0
# 48                                             0
# A                                              1
# AB                                             1
# AZ                                             5
# ...                                          ...
# wyoming                                        1
# yukon                                          1
# |NC                                            1
# ¯rb¾k                                          1
# NaN                                           38
#
#                                   Q6 | Hershey's Dark Chocolate  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                             0
# 48                                                            0
# A                                                             1
# AB                                                            1
# AZ                                                            5
# ...                                                         ...
# wyoming                                                       1
# yukon                                                         1
# |NC                                                           1
# ¯rb¾k                                                         1
# NaN                                                          41
#
#                                   Q6 | HersheyÕs Milk Chocolate  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                             0
# 48                                                            0
# A                                                             1
# AB                                                            1
# AZ                                                            5
# ...                                                         ...
# wyoming                                                       1
# yukon                                                         1
# |NC                                                           1
# ¯rb¾k                                                         1
# NaN                                                          41
#
#                                   Q6 | Hershey's Kisses  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                     0
# 48                                                    0
# A                                                     1
# AB                                                    1
# AZ                                                    5
# ...                                                 ...
# wyoming                                               1
# yukon                                                 1
# |NC                                                   1
# ¯rb¾k                                                 1
# NaN                                                  42
#
#                                   Q6 | Hugs (actual physical hugs)  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                0
# 48                                                               0
# A                                                                1
# AB                                                               1
# AZ                                                               5
# ...                                                            ...
# wyoming                                                          1
# yukon                                                            1
# |NC                                                              1
# ¯rb¾k                                                            1
# NaN                                                             39
#
#                                   Q6 | Jolly Rancher (bad flavor)  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                               0
# 48                                                              0
# A                                                               1
# AB                                                              1
# AZ                                                              5
# ...                                                           ...
# wyoming                                                         1
# yukon                                                           1
# |NC                                                             1
# ¯rb¾k                                                           1
# NaN                                                            40
#
#                                   Q6 | Jolly Ranchers (good flavor)  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                 0
# 48                                                                0
# A                                                                 1
# AB                                                                1
# AZ                                                                5
# ...                                                             ...
# wyoming                                                           1
# yukon                                                             1
# |NC                                                               1
# ¯rb¾k                                                             1
# NaN                                                              41
#
#                                   Q6 | JoyJoy (Mit Iodine!)  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                         0
# 48                                                        0
# A                                                         1
# AB                                                        0
# AZ                                                        5
# ...                                                     ...
# wyoming                                                   1
# yukon                                                     1
# |NC                                                       1
# ¯rb¾k                                                     1
# NaN                                                      26
#
#                                   Q6 | Junior Mints  Q6 | Senior Mints  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                 0                  0
# 48                                                0                  0
# A                                                 1                  1
# AB                                                0                  0
# AZ                                                5                  5
# ...                                             ...                ...
# wyoming                                           1                  1
# yukon                                             1                  1
# |NC                                               1                  1
# ¯rb¾k                                             1                  1
# NaN                                              39                 33
#
#                                   Q6 | Kale smoothie  Q6 | Kinder Happy Hippo  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                  0                        0
# 48                                                 0                        0
# A                                                  1                        1
# AB                                                 1                        1
# AZ                                                 5                        5
# ...                                              ...                      ...
# wyoming                                            1                        1
# yukon                                              1                        1
# |NC                                                1                        1
# ¯rb¾k                                              1                        1
# NaN                                               38                       29
#
#                                   Q6 | Kit Kat  Q6 | LaffyTaffy  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                            0                0
# 48                                           0                0
# A                                            1                1
# AB                                           1                1
# AZ                                           5                4
# ...                                        ...              ...
# wyoming                                      1                1
# yukon                                        1                1
# |NC                                          1                1
# ¯rb¾k                                        1                1
# NaN                                         41               37
#
#                                   Q6 | LemonHeads  Q6 | Licorice (not black)  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                               0                          0
# 48                                              0                          0
# A                                               1                          1
# AB                                              1                          1
# AZ                                              4                          5
# ...                                           ...                        ...
# wyoming                                         1                          1
# yukon                                           1                          1
# |NC                                             1                          1
# ¯rb¾k                                           1                          1
# NaN                                            38                         40
#
#                                   Q6 | Licorice (yes black)  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                         0
# 48                                                        0
# A                                                         1
# AB                                                        1
# AZ                                                        5
# ...                                                     ...
# wyoming                                                   1
# yukon                                                     1
# |NC                                                       1
# ¯rb¾k                                                     1
# NaN                                                      41
#
#                                   Q6 | Lindt Truffle  Q6 | Lollipops  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                  0               0
# 48                                                 0               0
# A                                                  1               1
# AB                                                 1               1
# AZ                                                 5               5
# ...                                              ...             ...
# wyoming                                            1               1
# yukon                                              1               1
# |NC                                                1               1
# ¯rb¾k                                              1               1
# NaN                                               39              40
#
#                                   Q6 | Mars  Q6 | Maynards  Q6 | Mike and Ike  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                         0              0                  0
# 48                                        0              0                  0
# A                                         1              1                  1
# AB                                        1              1                  1
# AZ                                        5              5                  5
# ...                                     ...            ...                ...
# wyoming                                   1              1                  1
# yukon                                     1              1                  1
# |NC                                       1              1                  1
# ¯rb¾k                                     1              1                  1
# NaN                                      39             29                 39
#
#                                   Q6 | Milk Duds  Q6 | Milky Way  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                              0               0
# 48                                             0               0
# A                                              1               1
# AB                                             1               1
# AZ                                             5               5
# ...                                          ...             ...
# wyoming                                        1               1
# yukon                                          1               1
# |NC                                            1               1
# ¯rb¾k                                          1               1
# NaN                                           40              41
#
#                                   Q6 | Regular M&Ms  Q6 | Peanut M&MÕs  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                 0                  0
# 48                                                0                  0
# A                                                 1                  1
# AB                                                1                  1
# AZ                                                5                  5
# ...                                             ...                ...
# wyoming                                           1                  1
# yukon                                             1                  1
# |NC                                               1                  1
# ¯rb¾k                                             1                  1
# NaN                                              41                 41
#
#                                   Q6 | Blue M&M's  Q6 | Red M&M's  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                               0               0
# 48                                              0               0
# A                                               1               1
# AB                                              1               1
# AZ                                              5               5
# ...                                           ...             ...
# wyoming                                         1               1
# yukon                                           1               1
# |NC                                             1               1
# ¯rb¾k                                           1               1
# NaN                                            38              38
#
#                                   Q6 | Green Party M&M's  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                      0
# 48                                                     0
# A                                                      1
# AB                                                     1
# AZ                                                     5
# ...                                                  ...
# wyoming                                                1
# yukon                                                  1
# |NC                                                    1
# ¯rb¾k                                                  1
# NaN                                                   36
#
#                                   Q6 | Independent M&M's  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                      0
# 48                                                     0
# A                                                      1
# AB                                                     1
# AZ                                                     5
# ...                                                  ...
# wyoming                                                1
# yukon                                                  1
# |NC                                                    1
# ¯rb¾k                                                  1
# NaN                                                   36
#
#                                   Q6 | Abstained from M&M'ing.  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                            0
# 48                                                           0
# A                                                            1
# AB                                                           0
# AZ                                                           5
# ...                                                        ...
# wyoming                                                      1
# yukon                                                        1
# |NC                                                          1
# ¯rb¾k                                                        1
# NaN                                                         30
#
#                                   Q6 | Minibags of chips  Q6 | Mint Kisses  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                      0                 0
# 48                                                     0                 0
# A                                                      1                 1
# AB                                                     0                 0
# AZ                                                     5                 5
# ...                                                  ...               ...
# wyoming                                                1                 1
# yukon                                                  1                 1
# |NC                                                    1                 1
# ¯rb¾k                                                  1                 1
# NaN                                                   39                39
#
#                                   Q6 | Mint Juleps  Q6 | Mr. Goodbar  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                0                 0
# 48                                               0                 0
# A                                                1                 1
# AB                                               0                 0
# AZ                                               5                 5
# ...                                            ...               ...
# wyoming                                          1                 1
# yukon                                            1                 0
# |NC                                              1                 1
# ¯rb¾k                                            1                 1
# NaN                                             36                37
#
#                                   Q6 | Necco Wafers  Q6 | Nerds  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                 0           0
# 48                                                0           0
# A                                                 1           1
# AB                                                0           1
# AZ                                                5           5
# ...                                             ...         ...
# wyoming                                           1           1
# yukon                                             1           1
# |NC                                               1           1
# ¯rb¾k                                             1           1
# NaN                                              39          39
#
#                                   Q6 | Nestle Crunch  Q6 | Now'n'Laters  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                  0                  0
# 48                                                 0                  0
# A                                                  1                  1
# AB                                                 1                  0
# AZ                                                 5                  5
# ...                                              ...                ...
# wyoming                                            1                  1
# yukon                                              1                  1
# |NC                                                1                  1
# ¯rb¾k                                              1                  1
# NaN                                               38                 33
#
#                                   Q6 | Peeps  Q6 | Pencils  Q6 | Pixy Stix  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                          0             0               0
# 48                                         0             0               0
# A                                          1             1               1
# AB                                         1             1               1
# AZ                                         5             5               5
# ...                                      ...           ...             ...
# wyoming                                    1             1               1
# yukon                                      1             1               1
# |NC                                        1             1               1
# ¯rb¾k                                      1             1               1
# NaN                                       40            40              39
#
#                                   Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                                 0
# 48                                                                                0
# A                                                                                 1
# AB                                                                                1
# AZ                                                                                5
# ...                                                                             ...
# wyoming                                                                           1
# yukon                                                                             1
# ...
# AB                                               1                  1
# AZ                                               5                  5
# ...                                            ...                ...
# wyoming                                          1                  1
# yukon                                            1                  1
# |NC                                              1                  1
# ¯rb¾k                                            1                  1
# NaN                                             38                 40
#
#                                   Q6 | Sweetums (a friend to diabetes)  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                    0
# 48                                                                   0
# A                                                                    1
# AB                                                                   0
# AZ                                                                   5
# ...                                                                ...
# wyoming                                                              1
# yukon                                                                0
# |NC                                                                  1
# ¯rb¾k                                                                1
# NaN                                                                 29
#
#                                   Q6 | Take 5  Q6 | Tic Tacs  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                           0              0
# 48                                          0              0
# A                                           1              1
# AB                                          0              1
# AZ                                          5              5
# ...                                       ...            ...
# wyoming                                     1              1
# yukon                                       0              1
# |NC                                         1              1
# ¯rb¾k                                       1              1
# NaN                                        31             39
#
#                                   Q6 | Those odd marshmallow circus peanut things  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                               0
# 48                                                                              0
# A                                                                               1
# AB                                                                              1
# AZ                                                                              5
# ...                                                                           ...
# wyoming                                                                         1
# yukon                                                                           1
# |NC                                                                             1
# ¯rb¾k                                                                           1
# NaN                                                                            39
#
#                                   Q6 | Three Musketeers  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                     0
# 48                                                    0
# A                                                     1
# AB                                                    1
# AZ                                                    5
# ...                                                 ...
# wyoming                                               1
# yukon                                                 1
# |NC                                                   1
# ¯rb¾k                                                 1
# NaN                                                  40
#
#                                   Q6 | Tolberone something or other  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                 0
# 48                                                                0
# A                                                                 1
# AB                                                                1
# AZ                                                                5
# ...                                                             ...
# wyoming                                                           1
# yukon                                                             1
# |NC                                                               1
# ¯rb¾k                                                             1
# NaN                                                              38
#
#                                   Q6 | Trail Mix  Q6 | Twix  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                              0          0
# 48                                             0          0
# A                                              1          1
# AB                                             1          1
# AZ                                             5          5
# ...                                          ...        ...
# wyoming                                        1          1
# yukon                                          1          1
# |NC                                            1          1
# ¯rb¾k                                          1          1
# NaN                                           36         39
#
#                                   Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                                                 0
# 48                                                                                0
# A                                                                                 1
# AB                                                                                1
# AZ                                                                                5
# ...                                                                             ...
# wyoming                                                                           1
# yukon                                                                             0
# |NC                                                                               1
# ¯rb¾k                                                                             1
# NaN                                                                              36
#
#                                   Q6 | Vicodin  Q6 | Whatchamacallit Bars  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                            0                          0
# 48                                           0                          0
# A                                            1                          1
# AB                                           1                          0
# AZ                                           5                          5
# ...                                        ...                        ...
# wyoming                                      1                          1
# yukon                                        0                          1
# |NC                                          1                          1
# ¯rb¾k                                        1                          1
# NaN                                         37                         37
#
#                                   Q6 | White Bread  Q6 | Whole Wheat anything  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                0                          0
# 48                                               0                          0
# A                                                1                          1
# AB                                               1                          1
# AZ                                               5                          5
# ...                                            ...                        ...
# wyoming                                          1                          1
# yukon                                            1                          1
# |NC                                              1                          1
# ¯rb¾k                                            1                          1
# NaN                                             38                         38
#
#                                   Q6 | York Peppermint Patties  Q7: JOY OTHER  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                            0              0
# 48                                                           0              0
# A                                                            1              1
# AB                                                           0              0
# AZ                                                           5              4
# ...                                                        ...            ...
# wyoming                                                      1              0
# yukon                                                        1              1
# |NC                                                          1              1
# ¯rb¾k                                                        1              1
# NaN                                                         39             16
#
#                                   Q8: DESPAIR OTHER  Q9: OTHER COMMENTS  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                 0                   0
# 48                                                0                   0
# A                                                 1                   1
# AB                                                0                   0
# AZ                                                4                   1
# ...                                             ...                 ...
# wyoming                                           0                   0
# yukon                                             1                   0
# |NC                                               1                   1
# ¯rb¾k                                             1                   1
# NaN                                               9                   7
#
#                                   Q10: DRESS  Unnamed: 113  Q11: DAY  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                          0             0         0
# 48                                         0             0         0
# A                                          1             0         1
# AB                                         1             0         1
# AZ                                         5             0         5
# ...                                      ...           ...       ...
# wyoming                                    1             0         1
# yukon                                      1             0         1
# |NC                                        1             0         1
# ¯rb¾k                                      1             0         1
# NaN                                       35             0        36
#
#                                   Q12: MEDIA [Daily Dish]  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                       0
# 48                                                      0
# A                                                       0
# AB                                                      0
# AZ                                                      0
# ...                                                   ...
# wyoming                                                 0
# yukon                                                   0
# |NC                                                     0
# ¯rb¾k                                                   0
# NaN                                                     2
#
#                                   Q12: MEDIA [Science]  Q12: MEDIA [ESPN]  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                    0                  0
# 48                                                   0                  0
# A                                                    1                  0
# AB                                                   0                  0
# AZ                                                   5                  0
# ...                                                ...                ...
# wyoming                                              1                  0
# yukon                                                1                  0
# |NC                                                  0                  0
# ¯rb¾k                                                1                  0
# NaN                                                 27                  3
#
#                                   Q12: MEDIA [Yahoo]  \
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                  0
# 48                                                 0
# A                                                  0
# AB                                                 0
# AZ                                                 0
# ...                                              ...
# wyoming                                            0
# yukon                                              0
# |NC                                                0
# ¯rb¾k                                              0
# NaN                                                3
#
#                                   Click Coordinates (x, y)  item_joy
# Q5: STATE, PROVINCE, COUNTY, ETC
# 1                                                        0         1
# 48                                                       0         1
# A                                                        1         1
# AB                                                       0         3
# AZ                                                       5         7
# ...                                                    ...       ...
# wyoming                                                  1         1
# yukon                                                    1         1
# |NC                                                      0         1
# ¯rb¾k                                                    1         1
# NaN                                                     35       100
#
# [512 rows x 120 columns]

# %%
# Renaming columns
df_candy_hier.rename(columns = {'Q5: STATE, PROVINCE, COUNTY, ETC':'state_county', 'Q4: COUNTRY':'country', 'Q3: AGE':'age', 'Q2: GENDER':'gender', 'Internal ID':'ID', 'Q11: DAY':'day'}, inplace = True)

# Another group by example to see grouped counts for single field
df_candy_hier.groupby('state_county', sort=True)['ID'].count()
# Out:
# state_county
# 1          1
# 48         1
# A          1
# AB         3
# AZ         7
#           ..
# wv         1
# wyoming    1
# yukon      1
# |NC        1
# ¯rb¾k      1
# Name: ID, Length: 511, dtype: int64

# %%
# creating a group by object and keepinmg it for further steps
by_state = df_candy_hier.groupby("state_county", sort=True)
print(by_state)

# The reason that a DataFrameGroupBy object can be difficult to wrap head around is 
# that it’s lazy in nature. It doesn’t really do any operations to produce a useful result until you tell it to.
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f9349e38a90>

# %% [markdown]
# ### Transform 6 (Chapter 10) : Split/Apply/Combine

# %%
# Here is what it means
# Split a table into groups.
# Apply some operations to each of those smaller tables.
# Combine the results.

# It can be difficult to inspect df_candy_hier.groupby("Q5: STATE, PROVINCE, COUNTY, ETC") because it does virtually none of 
# these things until you do something with the resulting object. A pandas GroupBy object delays virtually every part of the 
# split-apply-combine process until you invoke a method on it.

# %%
# See splitting in action by looping through grouped field
# for state_county, ID in by_state:
#   print(f"First 2 entries for {state_county!r}")
#   print("------------------------")
#   print(ID.head(2), end="\n\n")
    
    
# display values associated with one group 
by_state.groups["SC"]

# Each value is a sequence of the index locations for the rows belonging to that particular group. 
# In the output above, 175, 634, 1036, and 1945 are the first indices in df at which the state equals "SC".
# Out:
# Int64Index([175, 634, 1036, 1945], dtype='int64')

# %%
# apply part - We can think of this step of the process as applying the same operation (or callable) to 
# every sub-table that the splitting stage produces.

# For e.g. we can see count of number of records per group 
# df_candy_hier.groupby("state_county")["ID"].count()

by_state['ID'].count()
# Out:
# state_county
# 1          1
# 48         1
# A          1
# AB         3
# AZ         7
#           ..
# wv         1
# wyoming    1
# yukon      1
# |NC        1
# ¯rb¾k      1
# Name: ID, Length: 511, dtype: int64

# %%
# combine part - combine, takes the results of all of the applied operations on all of the sub-tables and 
# combines them back together in an intuitive way.

# We can get the counts per state and combine them into a new data frame
df_cnt_by_state_county = by_state.count()
df_cnt_by_state_county['ID'].head()
# Out:
# state_county
# 1     1
# 48    1
# A     1
# AB    3
# AZ    7
# Name: ID, dtype: int64

# %%
# Another example to show grouping by day
by_day = df_candy_hier.groupby("day", sort=True)

# %%
# apply mean() on groups and combine store into a new data frame
df_mean_by_day = by_day.mean()

# %%
# check the combined dataframe
df_mean_by_day.head()
# Out:
#                   ID  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# day
# Friday  9.028019e+07                      1.0                   1.0
# Sunday  9.027969e+07                      1.0                   1.0
#
#         Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo]
# day
# Friday                1.0                 1.0
# Sunday                1.0                 1.0

# %% [markdown]
# ### Transform 7 (Chapter 11) : Convert between string and datetime

# %%
df_met_filtered.head()
# Out:
#   Object Number Is Highlight Is Public Domain Object ID         Department  \
# 0    1979.486.1        FALSE            FALSE         1  The American Wing
# 1    1980.264.5        FALSE            FALSE         2  The American Wing
# 2      67.265.9        FALSE            FALSE         3  The American Wing
# 3     67.265.10        FALSE            FALSE         4  The American Wing
# 4     67.265.11        FALSE            FALSE         5  The American Wing
#
#   Object Name                         Title Culture Period Dynasty Reign  \
# 0        Coin  One-dollar Liberty Head Coin     NaN    NaN     NaN   NaN
# 1        Coin  Ten-dollar Liberty Head Coin     NaN    NaN     NaN   NaN
# 2        Coin    Two-and-a-Half Dollar Coin     NaN    NaN     NaN   NaN
# 3        Coin    Two-and-a-Half Dollar Coin     NaN    NaN     NaN   NaN
# 4        Coin    Two-and-a-Half Dollar Coin     NaN    NaN     NaN   NaN
#
#   Portfolio Artist Role Artist Prefix    Artist Display Name  \
# 0       NaN       Maker           NaN  James Barton Longacre
# 1       NaN       Maker           NaN     Christian Gobrecht
# 2       NaN         NaN           NaN                    NaN
# 3       NaN         NaN           NaN                    NaN
# 4       NaN         NaN           NaN                    NaN
#
#                                   Artist Display Bio Artist Suffix  \
# 0  American, Delaware County, Pennsylvania 1794Ð1...           NaN
# 1                                          1785Ð1844           NaN
# 2                                                NaN           NaN
# 3                                                NaN           NaN
# 4                                                NaN           NaN
#
#         Artist Alpha Sort Artist Nationality Artist Begin Date  \
# 0  Longacre, James Barton           American              1794
# 1     Gobrecht, Christian                NaN              1785
# 2                     NaN                NaN               NaN
# 3                     NaN                NaN               NaN
# 4                     NaN                NaN               NaN
#
#   Artist End Date Object Date Object Begin Date Object End Date Medium  \
# 0            1869        1853              1853            1853   Gold
# 1            1844        1901              1901            1901   Gold
# 2             NaN     1909Ð27              1909            1927   Gold
# 3             NaN     1909Ð27              1909            1927   Gold
# 4             NaN     1909Ð27              1909            1927   Gold
#
#                  Dimensions                         Credit Line  \
# 0    Dimensions unavailable  Gift of Heinz L. Stoppelmann, 1979
# 1    Dimensions unavailable  Gift of Heinz L. Stoppelmann, 1980
# 2  Diam. 11/16 in. (1.7 cm)   Gift of C. Ruxton Love, Jr., 1967
# 3  Diam. 11/16 in. (1.7 cm)   Gift of C. Ruxton Love, Jr., 1967
# 4  Diam. 11/16 in. (1.7 cm)   Gift of C. Ruxton Love, Jr., 1967
#
#   Geography Type City State County Country Region  Subregion Locale  Locus  \
# 0            NaN  NaN   NaN    NaN     NaN    NaN        NaN    NaN    NaN
# 1            NaN  NaN   NaN    NaN     NaN    NaN        NaN    NaN    NaN
# 2            NaN  NaN   NaN    NaN     NaN    NaN        NaN    NaN    NaN
# 3            NaN  NaN   NaN    NaN     NaN    NaN        NaN    NaN    NaN
# 4            NaN  NaN   NaN    NaN     NaN    NaN        NaN    NaN    NaN
#
#   Excavation  River Classification Rights and Reproduction  \
# 0        NaN    NaN          Metal                     NaN
# 1        NaN    NaN          Metal                     NaN
# 2        NaN    NaN          Metal                     NaN
# 3        NaN    NaN          Metal                     NaN
# 4        NaN    NaN          Metal                     NaN
#
#                                       Link Resource Metadata Date  \
# 0  http://www.metmuseum.org/art/collection/search/1           NaN
# 1  http://www.metmuseum.org/art/collection/search/2           NaN
# 2  http://www.metmuseum.org/art/collection/search/3           NaN
# 3  http://www.metmuseum.org/art/collection/search/4           NaN
# 4  http://www.metmuseum.org/art/collection/search/5           NaN
#
#                                  Repository Tags
# 0  Metropolitan Museum of Art, New York, NY  NaN
# 1  Metropolitan Museum of Art, New York, NY  NaN
# 2  Metropolitan Museum of Art, New York, NY  NaN
# 3  Metropolitan Museum of Art, New York, NY  NaN
# 4  Metropolitan Museum of Art, New York, NY  NaN

# %%
# We are interested in "Object Begin Date" and "Object End Date"
# Lets rename these columns to get rid of spaces
df_met_filtered.rename(columns = {'Object Begin Date':'obj_begin_dt', 'Object End Date':'obj_end_dt'}, inplace = True)

# %%
# Check unique value counts
df_met_filtered['obj_begin_dt'].nunique()
# Out:
# 275

# %%
df_met_filtered['obj_end_dt'].nunique()
# Out:
# 264

# %%
# filter out any records with "obj_begin_dt" null or "obj_end_dt" null
df_met_filtered = df_met_filtered[~df_met_filtered['obj_begin_dt'].isnull()]
df_met_filtered = df_met_filtered[~df_met_filtered['obj_end_dt'].isnull()]


# see all unique values
df_met_filtered['obj_begin_dt'].unique()
# Out:
# array(['1853', '1901', '1909', '1912', '1907', '1876', '1910', '1665',
#        '1800', '1867', '1860', '1859', '1881', '1878', '1885', '1866',
#        '1847', '1893', '1884', '1782', '1770', '1830', '1850', '1795',
#        '1787', '1700', '1797', '1760', '1750', '1740', '1697', '1730',
#        '1790', '1792', '1803', '1807', '1777', '1894', '1868', '1870',
#        '1822', '1902', '1827', '1835', '1647', '1650', '1720', '1889',
#        '1710', '1775', '1690', '1675', '1660', '1785', '1725', '1752',
#        '1815', '1735', '1755', '1875', '1640', '1630', '1862', '1805',
#        '1872', '1852', '1794', '1765', '1865', '1897', '1820', '1877',
#        '1911', '1857', '1801', '1832', '1888', '1890', '1838', '1791',
#        '1810', '1887', '1899', '1923', '1780', '1896', '1891', '1813',
#        '1833', '1840', '1825', '1719', '1821', '1819', '1892', '1817',
#        '1849', '1846', '1756', '1712', '1880', '1670', '1762', '1680',
#        '1789', '1773', '1667', '1831', '1772', '1727', '1711', '1814',
#        '1829', '1716', '1916', '1776', '1851', '1778', '1864', '1600',
#        '1674', '1744', '1784', '1802', '1769', '1786', '1788', '1808',
#        '1715', '1882', '1883', '1809', '1763', '1641', '1757', '1738',
#        '1747', '1837', '1736', '1886', '1748', '1895', '1844', '1811',
#        '1908', '1915', '1905', '1898', '1842', '1705', '1869', '1919',
#        '1900', '1793', '1679', '1856', '1874', '1863', '1929', '1873',
#        '1783', '1722', '1732', '1737', '1845', '1702', '1879', '1922',
#        '1717', '1917', '1824', '1904', '1764', '1718', '1695', '1767',
#        '1812', '1937', '1934', '1816', '1677', '1861', '1685', '1663',
#        '1796', '1841', '1903', '1781', '1745', '1761', '1855', '1921',
#        '1854', '1753', '1739', '1976', '1828', '1843', '0', '1779',
#        '1848', '1751', '1729', '1826', '1858', '1927', '1696', '1836',
#        '1906', '1759', '1713', '1774', '1806', '1749', '1818', '1952',
#        '1758', '1918', 'Rogers Fund, 1916', '1914', '1703', '1839',
#        '1834', '1731', '1913', '1644', '1925', '1682', '1723', '1799',
#        '1798', '1924', '1658', '1823', '1733', '1766', '1726', '1928',
#        '1768', '1704', '1804', '1707', '1698', '1754', '1684', '1701',
#        '1652', '1662', '1699', '1709', '1742', '1687', '1871', '1771',
#        '1688', '1653', '1672', '1930', '1940', '1926', '1935', '1746',
#        '1932', '1950', '1956', '1933', '1708', '1920', '1943', '1969',
#        '1939', '1931', '1947', '1944'], dtype=object)

# %%
# It seems there is a not year string value - 'Caryatids' which needs to be taken care before we can play with dates
# We can modify this date to be high date i.e. '9999'
# Replace 'Rogers Fund, 1916' with 1916
df_met_filtered['obj_begin_dt'] = df_met_filtered['obj_begin_dt'].replace(['Caryatids','0'], '9999')
df_met_filtered['obj_begin_dt'] = df_met_filtered['obj_begin_dt'].replace(['Rogers Fund, 1916'], '1916')

# %%
# check unique values again
df_met_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10829 entries, 0 to 12106
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Object Number            10829 non-null  object
#  1   Is Highlight             10829 non-null  object
#  2   Is Public Domain         10829 non-null  object
#  3   Object ID                10829 non-null  object
#  4   Department               10828 non-null  object
#  5   Object Name              10828 non-null  object
#  6   Title                    10828 non-null  object
#  7   Culture                  9112 non-null   object
#  8   Period                   0 non-null      object
#  9   Dynasty                  0 non-null      object
#  10  Reign                    0 non-null      object
#  11  Portfolio                0 non-null      object
#  12  Artist Role              5534 non-null   object
#  13  Artist Prefix            1261 non-null   object
#  14  Artist Display Name      5534 non-null   object
#  15  Artist Display Bio       5140 non-null   object
#  16  Artist Suffix            48 non-null     object
#  17  Artist Alpha Sort        5524 non-null   object
#  18  Artist Nationality       2109 non-null   object
#  19  Artist Begin Date        5139 non-null   object
#  20  Artist End Date          5488 non-null   object
#  21  Object Date              10636 non-null  object
#  22  obj_begin_dt             10829 non-null  object
#  23  obj_end_dt               10829 non-null  object
#  24  Medium                   10828 non-null  object
#  25  Dimensions               10776 non-null  object
#  26  Credit Line              10082 non-null  object
#  27  Geography Type           7319 non-null   object
#  28  City                     3997 non-null   object
#  29  State                    654 non-null    object
#  30  County                   655 non-null    object
#  31  Country                  7316 non-null   object
#  32  Region                   356 non-null    object
#  33  Subregion                0 non-null      float64
#  34  Locale                   1 non-null      object
#  35  Locus                    0 non-null      float64
#  36  Excavation               1 non-null      object
#  37  River                    0 non-null      float64
#  38  Classification           10080 non-null  object
#  39  Rights and Reproduction  71 non-null     object
#  40  Link Resource            10079 non-null  object
#  41  Metadata Date            8680 non-null   object
#  42  Repository               10079 non-null  object
#  43  Tags                     3865 non-null   object
# dtypes: float64(3), object(41)
# memory usage: 3.7+ MB

# %%
# Changing all year values to year-01-01
df_met_filtered['obj_begin_dt'] = df_met_filtered['obj_begin_dt'].astype('str') + "-01-01"

# %%
# check unique values now
df_met_filtered['obj_begin_dt'].unique()
# Out:
# array(['1853-01-01', '1901-01-01', '1909-01-01', '1912-01-01',
#        '1907-01-01', '1876-01-01', '1910-01-01', '1665-01-01',
#        '1800-01-01', '1867-01-01', '1860-01-01', '1859-01-01',
#        '1881-01-01', '1878-01-01', '1885-01-01', '1866-01-01',
#        '1847-01-01', '1893-01-01', '1884-01-01', '1782-01-01',
#        '1770-01-01', '1830-01-01', '1850-01-01', '1795-01-01',
#        '1787-01-01', '1700-01-01', '1797-01-01', '1760-01-01',
#        '1750-01-01', '1740-01-01', '1697-01-01', '1730-01-01',
#        '1790-01-01', '1792-01-01', '1803-01-01', '1807-01-01',
#        '1777-01-01', '1894-01-01', '1868-01-01', '1870-01-01',
#        '1822-01-01', '1902-01-01', '1827-01-01', '1835-01-01',
#        '1647-01-01', '1650-01-01', '1720-01-01', '1889-01-01',
#        '1710-01-01', '1775-01-01', '1690-01-01', '1675-01-01',
#        '1660-01-01', '1785-01-01', '1725-01-01', '1752-01-01',
#        '1815-01-01', '1735-01-01', '1755-01-01', '1875-01-01',
#        '1640-01-01', '1630-01-01', '1862-01-01', '1805-01-01',
#        '1872-01-01', '1852-01-01', '1794-01-01', '1765-01-01',
#        '1865-01-01', '1897-01-01', '1820-01-01', '1877-01-01',
#        '1911-01-01', '1857-01-01', '1801-01-01', '1832-01-01',
#        '1888-01-01', '1890-01-01', '1838-01-01', '1791-01-01',
#        '1810-01-01', '1887-01-01', '1899-01-01', '1923-01-01',
#        '1780-01-01', '1896-01-01', '1891-01-01', '1813-01-01',
#        '1833-01-01', '1840-01-01', '1825-01-01', '1719-01-01',
#        '1821-01-01', '1819-01-01', '1892-01-01', '1817-01-01',
#        '1849-01-01', '1846-01-01', '1756-01-01', '1712-01-01',
#        '1880-01-01', '1670-01-01', '1762-01-01', '1680-01-01',
#        '1789-01-01', '1773-01-01', '1667-01-01', '1831-01-01',
#        '1772-01-01', '1727-01-01', '1711-01-01', '1814-01-01',
#        '1829-01-01', '1716-01-01', '1916-01-01', '1776-01-01',
#        '1851-01-01', '1778-01-01', '1864-01-01', '1600-01-01',
#        '1674-01-01', '1744-01-01', '1784-01-01', '1802-01-01',
#        '1769-01-01', '1786-01-01', '1788-01-01', '1808-01-01',
#        '1715-01-01', '1882-01-01', '1883-01-01', '1809-01-01',
#        '1763-01-01', '1641-01-01', '1757-01-01', '1738-01-01',
#        '1747-01-01', '1837-01-01', '1736-01-01', '1886-01-01',
#        '1748-01-01', '1895-01-01', '1844-01-01', '1811-01-01',
#        '1908-01-01', '1915-01-01', '1905-01-01', '1898-01-01',
#        '1842-01-01', '1705-01-01', '1869-01-01', '1919-01-01',
#        '1900-01-01', '1793-01-01', '1679-01-01', '1856-01-01',
#        '1874-01-01', '1863-01-01', '1929-01-01', '1873-01-01',
#        '1783-01-01', '1722-01-01', '1732-01-01', '1737-01-01',
#        '1845-01-01', '1702-01-01', '1879-01-01', '1922-01-01',
#        '1717-01-01', '1917-01-01', '1824-01-01', '1904-01-01',
#        '1764-01-01', '1718-01-01', '1695-01-01', '1767-01-01',
#        '1812-01-01', '1937-01-01', '1934-01-01', '1816-01-01',
#        '1677-01-01', '1861-01-01', '1685-01-01', '1663-01-01',
#        '1796-01-01', '1841-01-01', '1903-01-01', '1781-01-01',
#        '1745-01-01', '1761-01-01', '1855-01-01', '1921-01-01',
#        '1854-01-01', '1753-01-01', '1739-01-01', '1976-01-01',
#        '1828-01-01', '1843-01-01', '9999-01-01', '1779-01-01',
#        '1848-01-01', '1751-01-01', '1729-01-01', '1826-01-01',
#        '1858-01-01', '1927-01-01', '1696-01-01', '1836-01-01',
#        '1906-01-01', '1759-01-01', '1713-01-01', '1774-01-01',
#        '1806-01-01', '1749-01-01', '1818-01-01', '1952-01-01',
#        '1758-01-01', '1918-01-01', '1914-01-01', '1703-01-01',
#        '1839-01-01', '1834-01-01', '1731-01-01', '1913-01-01',
#        '1644-01-01', '1925-01-01', '1682-01-01', '1723-01-01',
#        '1799-01-01', '1798-01-01', '1924-01-01', '1658-01-01',
#        '1823-01-01', '1733-01-01', '1766-01-01', '1726-01-01',
#        '1928-01-01', '1768-01-01', '1704-01-01', '1804-01-01',
#        '1707-01-01', '1698-01-01', '1754-01-01', '1684-01-01',
#        '1701-01-01', '1652-01-01', '1662-01-01', '1699-01-01',
#        '1709-01-01', '1742-01-01', '1687-01-01', '1871-01-01',
#        '1771-01-01', '1688-01-01', '1653-01-01', '1672-01-01',
#        '1930-01-01', '1940-01-01', '1926-01-01', '1935-01-01',
#        '1746-01-01', '1932-01-01', '1950-01-01', '1956-01-01',
#        '1933-01-01', '1708-01-01', '1920-01-01', '1943-01-01',
#        '1969-01-01', '1939-01-01', '1931-01-01', '1947-01-01',
#        '1944-01-01'], dtype=object)

# %%
# changing string to datetime format
df_met_filtered["obj_begin_dt"] = pd.to_datetime(df_met_filtered["obj_begin_dt"], errors='coerce')

# %%
# check unique values in end date
df_met_filtered['obj_end_dt'].unique()
# Out:
# array(['1853', '1901', '1927', '1912', '1907', '1876', '1910', '1700',
#        '1900', '1867', '1860', '1859', '1881', '1878', '1870', '1885',
#        '1866', '1850', '1895', '1887', '1785', '1800', '1810', '1790',
#        '1830', '1780', '1765', '1760', '1770', '1815', '1820', '1814',
#        '1828', '1894', '1740', '1825', '1908', '1840', '1650', '1730',
#        '1889', '1690', '1750', '1775', '1710', '1795', '1745', '1755',
#        '1725', '1680', '1743', '1863', '1875', '1858', '1794', '1904',
#        '1823', '1886', '1914', '1897', '1801', '1813', '1835', '1880',
#        '1893', '1805', '1848', '1818', '1890', '1903', '1855', '1924',
#        '1783', '1793', '1816', '1807', '1845', '1758', '1846', '1837',
#        '1809', '1833', '1754', '1888', '1776', '1683', '1824', '1789',
#        '1796', '1768', '1856', '1670', '1778', '1720', '1839', '1711',
#        '1719', '1797', '1884', '1865', '1916', '1883', '1851', '1777',
#        '1847', '1674', '1792', '1744', '1920', '1868', '1787', '1822',
#        '1784', '1802', '1769', '1803', '1782', '1786', '1788', '1808',
#        '1819', '1919', '1849', '1728', '1882', '1812', '1779', '1644',
#        '1774', '1751', '1896', '1811', '1917', '1821', '1925', '1911',
#        '1902', '1899', '1715', '1685', '1915', '1852', '1869', '1857',
#        '1922', '1957', '1913', '1905', '1679', '1929', '1836', '1735',
#        '1708', '1763', '1766', '1921', '1718', '1804', '1773', '1737',
#        '1877', '2000', '1799', '1940', '1937', '1879', '1930', '1909',
#        '1772', '1705', '1827', '1931', '1767', '1762', '1798', '1838',
#        '1727', '1861', '1862', '1741', '1976', '1747', '1739', '0',
#        '1892', '1874', '1871', '1844', '1749', '1829', '1832', '1699',
#        '1841', '1950', '1781', '1742', '1906', '1834', '1764', '1918',
#        '1843', '1955', '1817', '1891', '1898', 'Made in', '1864', '1923',
#        '1703', '1873', '1756', '1960', '1806', '1688', '1791', '1759',
#        '1731', '1647', '1831', '1761', '1854', '1757', '1658', '1983',
#        '1733', '1736', '1934', '1722', '1932', '1704', '1771', '1826',
#        '1959', '1702', '1738', '1687', '1872', '1926', '1842', '1652',
#        '1684', '1698', '1753', '1938', '1933', '1691', '1656', '1675',
#        '1935', '1951', '1941', '1956', '1928', '1746', '1944', '1963',
#        '1958', '1962', '1943', '1969', '1939', '1949', '1947', '1961'],
#       dtype=object)

# %%
# Replace non date values
df_met_filtered['obj_end_dt'] = df_met_filtered['obj_end_dt'].replace(['Made in','0'], '9999')

# %%
# check unique values
df_met_filtered['obj_end_dt'].unique()
# Out:
# array(['1853', '1901', '1927', '1912', '1907', '1876', '1910', '1700',
#        '1900', '1867', '1860', '1859', '1881', '1878', '1870', '1885',
#        '1866', '1850', '1895', '1887', '1785', '1800', '1810', '1790',
#        '1830', '1780', '1765', '1760', '1770', '1815', '1820', '1814',
#        '1828', '1894', '1740', '1825', '1908', '1840', '1650', '1730',
#        '1889', '1690', '1750', '1775', '1710', '1795', '1745', '1755',
#        '1725', '1680', '1743', '1863', '1875', '1858', '1794', '1904',
#        '1823', '1886', '1914', '1897', '1801', '1813', '1835', '1880',
#        '1893', '1805', '1848', '1818', '1890', '1903', '1855', '1924',
#        '1783', '1793', '1816', '1807', '1845', '1758', '1846', '1837',
#        '1809', '1833', '1754', '1888', '1776', '1683', '1824', '1789',
#        '1796', '1768', '1856', '1670', '1778', '1720', '1839', '1711',
#        '1719', '1797', '1884', '1865', '1916', '1883', '1851', '1777',
#        '1847', '1674', '1792', '1744', '1920', '1868', '1787', '1822',
#        '1784', '1802', '1769', '1803', '1782', '1786', '1788', '1808',
#        '1819', '1919', '1849', '1728', '1882', '1812', '1779', '1644',
#        '1774', '1751', '1896', '1811', '1917', '1821', '1925', '1911',
#        '1902', '1899', '1715', '1685', '1915', '1852', '1869', '1857',
#        '1922', '1957', '1913', '1905', '1679', '1929', '1836', '1735',
#        '1708', '1763', '1766', '1921', '1718', '1804', '1773', '1737',
#        '1877', '2000', '1799', '1940', '1937', '1879', '1930', '1909',
#        '1772', '1705', '1827', '1931', '1767', '1762', '1798', '1838',
#        '1727', '1861', '1862', '1741', '1976', '1747', '1739', '9999',
#        '1892', '1874', '1871', '1844', '1749', '1829', '1832', '1699',
#        '1841', '1950', '1781', '1742', '1906', '1834', '1764', '1918',
#        '1843', '1955', '1817', '1891', '1898', '1864', '1923', '1703',
#        '1873', '1756', '1960', '1806', '1688', '1791', '1759', '1731',
#        '1647', '1831', '1761', '1854', '1757', '1658', '1983', '1733',
#        '1736', '1934', '1722', '1932', '1704', '1771', '1826', '1959',
#        '1702', '1738', '1687', '1872', '1926', '1842', '1652', '1684',
#        '1698', '1753', '1938', '1933', '1691', '1656', '1675', '1935',
#        '1951', '1941', '1956', '1928', '1746', '1944', '1963', '1958',
#        '1962', '1943', '1969', '1939', '1949', '1947', '1961'],
#       dtype=object)

# %%
# Changing all year values to year-01-01
df_met_filtered['obj_end_dt'] = df_met_filtered['obj_end_dt'].astype('str') + "-12-31"

# %%
# convert into date time
df_met_filtered["obj_end_dt"] = pd.to_datetime(df_met_filtered["obj_end_dt"], errors='coerce')

# %% [markdown]
# ### Transform 8 (Chapter 11) : Generate date range

# %%
df_met_filtered[['obj_begin_dt','obj_end_dt']].head()
# Out:
#   obj_begin_dt obj_end_dt
# 0   1853-01-01 1853-12-31
# 1   1901-01-01 1901-12-31
# 2   1909-01-01 1927-12-31
# 3   1909-01-01 1927-12-31
# 4   1909-01-01 1927-12-31
